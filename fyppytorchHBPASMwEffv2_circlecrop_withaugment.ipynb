# %%
import torch
import torch.optim as optim
import torchvision.transforms as transforms
import torch.nn as nn
import HBPASM.data.data as data
import os
import torch.backends.cudnn as cudnn
from PIL import Image
import HBPASM.model.HBPASM_model as HBPASM_model
from torchvision import datasets, ops
from HBPASM.utils.utils import progress_bar
import torchmetrics
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
from torchsummary import summary
import time
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import math
from torch.optim.lr_scheduler import LambdaLR
from torchvision.datasets import ImageFolder
from torchvision.transforms import ToTensor, Lambda
from focal_loss import FocalLoss
import torchvision
from albumentations.core.transforms_interface import DualTransform
import albumentations as A
from albumentations.pytorch import ToTensorV2
import differaugment as augment
from Ranger21.ranger21.ranger21 import Ranger21
import custom_utils as custom_utils
from WeightedKappaLoss import WeightedKappaLoss
import torchvision.transforms.functional as F
from sklearn.model_selection import KFold
from ordinalencodedmodel import ModelVer1,ModelVer1FocalLosswithSGD,ModelVer1FocalLossonly
import encodetestoptimizermodel as optimizermodel
from typing import Any, Callable, Optional, Tuple
from torchvision.datasets.folder import DatasetFolder, default_loader, IMG_EXTENSIONS
import copy

    

class CustomImageFolder(DatasetFolder):
    def __init__(
        self,
        root: str,
        transform: Optional[Callable] = None,
        target_transform: Optional[Callable] = None,
        loader: Callable[[str], Any] = default_loader,
        is_valid_file: Optional[Callable[[str], bool]] = None,
    ):
        super().__init__(
            root,
            loader,
            IMG_EXTENSIONS if is_valid_file is None else None,
            transform=transform,
            target_transform=target_transform,
            is_valid_file=is_valid_file,
        )
        self.imgs = self.samples

    def __getitem__(self, index: int) -> Tuple[Any, Any]:
        """
        Args:
            index (int): Index

        Returns:
            tuple: (sample, target) where target is class_index of the target class.
        """
        path, target = self.samples[index]
        sample = self.loader(path)
        if self.transform is not None:
            try:
                sample = self.transform(sample)
            except Exception:
                sample = self.transform(image=np.array(sample))["image"]
        if self.target_transform is not None:
            target = self.target_transform(target)

        return sample, target

    def __len__(self) -> int:
        return len(self.samples)

# %% [markdown]
# # normal aug

# %%
IMG_SIZE=300
image_dir = os.path.join('..', 'dataset','ben processed circle crop','deepdridtrain')
trainset = datasets.ImageFolder(image_dir, transform=transforms.Compose([
                                                transforms.Resize((IMG_SIZE, IMG_SIZE), Image.BILINEAR),
                                                transforms.RandomHorizontalFlip(),
                                                transforms.RandomVerticalFlip(),
                                                transforms.ToTensor(),
                                                ]))
trainloader = torch.utils.data.DataLoader(trainset, batch_size=16,
                                          shuffle=True, num_workers=4)

image_dir = os.path.join('..', 'dataset','ben processed circle crop','deepdridvalid')
testset = datasets.ImageFolder(image_dir, transform=transforms.Compose([
                                                transforms.Resize((IMG_SIZE, IMG_SIZE), Image.BILINEAR),
                                                transforms.ToTensor(),
                                                ]))
testloader = torch.utils.data.DataLoader(testset, batch_size=16,
                                         shuffle=False, num_workers=4)
cudnn.benchmark = True
model=optimizermodel.ModelRanger21(filename='HBPASMwithEffv2_ranger21_300circlecrop_normalaug',lr=0.001,num_batches_per_epoch=len(trainloader))

df=model.traintest(150,trainloader,testloader)
custom_utils.plot_metrics(df)
custom_utils.plot_confusion_matrix_with_max_qwk(df)
torch.cuda.empty_cache()
# Out:
# Model : HBPASM with EfficientNetv2
# Ranger21 optimizer ready with following settings:
#
# Core optimizer = AdamW
# Learning rate of 0.001
#
# Important - num_epochs of training = ** 150 epochs **
# please confirm this is correct or warmup and warmdown will be off
#
# Warm-up: linear warmup, over 2000 iterations
#
# Lookahead active, merging every 5 steps, with blend factor of 0.5
# Norm Loss active, factor = 0.0001
# Stable weight decay of 0.0001
# Gradient Centralization = On
#
# Adaptive Gradient Clipping = True
# 	clipping value of 0.01
# 	steps for clipping = 0.001
#
# Warm-down: Linear warmdown, starting at 72.0%, iteration 8100 of 11250
# warm down will decay until 3e-05 lr
# ----------------------------------------Epoch: 1----------------------------------------
# params size saved
# total param groups = 1
# total params in groups = 466
#  [=======================================>]  Step: 2s996ms | Tot: 3m1s | loss: 1.9957 | tra 75/75   5
#
# Train set: Average loss: 2.0223, Cohen's Kappa: 0.0060, QWK Score: 0.0086, Accuracy: (25.08%), F1-Score: 0.1513, Specificity: 0.8022
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 705ms | Tot: 8s495ms | test 25/25 ==========>............................]  Step: 65ms | Tot: 2s367ms | test  8/25 =================>......................]  Step: 67ms | Tot: 4s97ms | test   12/25 ==============================>.........]  Step: 62ms | Tot: 6s581ms | test  20/25 ====================================>...]  Step: 61ms | Tot: 7s790ms | test  24/25
#
# Test set: Average loss: 0.1256, Accuracy: 174/400 (43.50%), Cohen's Kappa: 0.0014, QWK Score: 0.0040, F1-Score: 0.1215, Specificity: 0.8003
# Best qwk improved from 0.0000 to 0.0040
# ----------------------------------------Epoch: 2----------------------------------------
#  [=======================================>]  Step: 317ms | Tot: 24s840ms | loss: 1.8861 | tra 75/75
#
# Train set: Average loss: 1.9692, Cohen's Kappa: 0.0000, QWK Score: 0.0000, Accuracy: (45.00%), F1-Score: 0.1241, Specificity: 0.8000
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 511ms | Tot: 5s284ms | test 25/25 ================>.......................]  Step: 72ms | Tot: 1s898ms | test  11/25
#
# Test set: Average loss: 0.1207, Accuracy: 174/400 (43.50%), Cohen's Kappa: 0.0000, QWK Score: 0.0000, F1-Score: 0.1213, Specificity: 0.8000
# QWK did not improved from 0.0040
# ----------------------------------------Epoch: 3----------------------------------------
#  [=======================================>]  Step: 342ms | Tot: 24s565ms | loss: 1.3391 | tra 75/75
#
# Train set: Average loss: 1.7421, Cohen's Kappa: 0.1010, QWK Score: 0.2173, Accuracy: (48.42%), F1-Score: 0.1906, Specificity: 0.8181
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 441ms | Tot: 5s272ms | test 25/25
#
# Test set: Average loss: 0.1132, Accuracy: 220/400 (55.00%), Cohen's Kappa: 0.3351, QWK Score: 0.6632, F1-Score: 0.2652, Specificity: 0.8704
# Best qwk improved from 0.0040 to 0.6632
# ----------------------------------------Epoch: 4----------------------------------------
#  [=======================================>]  Step: 322ms | Tot: 24s541ms | loss: 1.4845 | tra 75/75
#
# Train set: Average loss: 1.3471, Cohen's Kappa: 0.3133, QWK Score: 0.6195, Accuracy: (55.58%), F1-Score: 0.2594, Specificity: 0.8639
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 528ms | Tot: 5s225ms | test 25/25 ===>...................................]  Step: 64ms | Tot: 194ms | test    4/25 ============================>...........]  Step: 65ms | Tot: 3s705ms | test  19/25 ===================================>....]  Step: 67ms | Tot: 4s621ms | test  23/25
#
# Test set: Average loss: 0.1067, Accuracy: 225/400 (56.25%), Cohen's Kappa: 0.3011, QWK Score: 0.5890, F1-Score: 0.2752, Specificity: 0.8562
# QWK did not improved from 0.6632
# ----------------------------------------Epoch: 5----------------------------------------
#  [=======================================>]  Step: 335ms | Tot: 24s625ms | loss: 1.5935 | tra 75/75
#
# Train set: Average loss: 1.0270, Cohen's Kappa: 0.3610, QWK Score: 0.7053, Accuracy: (58.25%), F1-Score: 0.2796, Specificity: 0.8742
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 485ms | Tot: 5s336ms | test 25/25 ==>....................................]  Step: 92ms | Tot: 198ms | test    3/25 ========================>...............]  Step: 65ms | Tot: 2s979ms | test  16/25 ===================================>....]  Step: 192ms | Tot: 4s789ms | test 23/25
#
# Test set: Average loss: 0.0967, Accuracy: 237/400 (59.25%), Cohen's Kappa: 0.3799, QWK Score: 0.7521, F1-Score: 0.2969, Specificity: 0.8764
# Best qwk improved from 0.6632 to 0.7521
# ----------------------------------------Epoch: 6----------------------------------------
#  [=======================================>]  Step: 325ms | Tot: 24s859ms | loss: 0.6226 | tra 75/75
#
# Train set: Average loss: 0.9237, Cohen's Kappa: 0.3706, QWK Score: 0.7218, Accuracy: (58.25%), F1-Score: 0.2935, Specificity: 0.8773
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 483ms | Tot: 5s225ms | test 25/25 ===>...................................]  Step: 65ms | Tot: 200ms | test    4/25 ===========>............................]  Step: 64ms | Tot: 1s68ms | test   8/25 ========================>...............]  Step: 64ms | Tot: 2s847ms | test  16/25 ==============================>.........]  Step: 63ms | Tot: 3s809ms | test  20/25
#
# Test set: Average loss: 0.0933, Accuracy: 240/400 (60.00%), Cohen's Kappa: 0.3934, QWK Score: 0.7743, F1-Score: 0.3104, Specificity: 0.8794
# Best qwk improved from 0.7521 to 0.7743
# ----------------------------------------Epoch: 7----------------------------------------
#  [=======================================>]  Step: 325ms | Tot: 24s724ms | loss: 0.5309 | tra 75/75
#
# Train set: Average loss: 0.7609, Cohen's Kappa: 0.4223, QWK Score: 0.7872, Accuracy: (61.42%), F1-Score: 0.3433, Specificity: 0.8877
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 487ms | Tot: 5s327ms | test 25/25 ==>....................................]  Step: 132ms | Tot: 195ms | test   3/25 ====>...................................]  Step: 67ms | Tot: 262ms | test    4/25 =========>..............................]  Step: 108ms | Tot: 1s67ms | test  7/25 ==============================>.........]  Step: 64ms | Tot: 3s901ms | test  20/25 ====================================>...]  Step: 64ms | Tot: 4s839ms | test  24/25
#
# Test set: Average loss: 0.0886, Accuracy: 255/400 (63.75%), Cohen's Kappa: 0.4682, QWK Score: 0.8245, F1-Score: 0.4023, Specificity: 0.8962
# Best qwk improved from 0.7743 to 0.8245
# ----------------------------------------Epoch: 8----------------------------------------
#  [=======================================>]  Step: 330ms | Tot: 24s717ms | loss: 0.7185 | tra 75/75
#
# Train set: Average loss: 0.6806, Cohen's Kappa: 0.4541, QWK Score: 0.8211, Accuracy: (62.25%), F1-Score: 0.4051, Specificity: 0.8962
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 477ms | Tot: 5s231ms | test 25/25 ========>..............................]  Step: 63ms | Tot: 1s81ms | test   7/25 ====================>...................]  Step: 203ms | Tot: 2s792ms | test 14/25
#
# Test set: Average loss: 0.0900, Accuracy: 246/400 (61.50%), Cohen's Kappa: 0.4533, QWK Score: 0.8043, F1-Score: 0.4182, Specificity: 0.8960
# QWK did not improved from 0.8245
# ----------------------------------------Epoch: 9----------------------------------------
#  [=======================================>]  Step: 320ms | Tot: 24s679ms | loss: 0.4766 | tra 75/75
#
# Train set: Average loss: 0.6114, Cohen's Kappa: 0.4919, QWK Score: 0.8389, Accuracy: (64.58%), F1-Score: 0.4399, Specificity: 0.9045
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 424ms | Tot: 5s242ms | test 25/25 ==========>............................]  Step: 64ms | Tot: 1s84ms | test   8/25 ================>.......................]  Step: 116ms | Tot: 1s904ms | test 11/25 ========================>...............]  Step: 62ms | Tot: 2s878ms | test  16/25
#
# Test set: Average loss: 0.0881, Accuracy: 265/400 (66.25%), Cohen's Kappa: 0.5289, QWK Score: 0.8364, F1-Score: 0.4936, Specificity: 0.9108
# Best qwk improved from 0.8245 to 0.8364
# ----------------------------------------Epoch: 10----------------------------------------
#  [=======================================>]  Step: 327ms | Tot: 24s586ms | loss: 0.3839 | tra 75/75
#
# Train set: Average loss: 0.5749, Cohen's Kappa: 0.5211, QWK Score: 0.8542, Accuracy: (66.83%), F1-Score: 0.4617, Specificity: 0.9094
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 403ms | Tot: 5s277ms | test 25/25 ==>....................................]  Step: 132ms | Tot: 197ms | test   3/25 ====>...................................]  Step: 63ms | Tot: 261ms | test    4/25 ===================================>....]  Step: 181ms | Tot: 4s809ms | test 23/25
#
# Test set: Average loss: 0.0899, Accuracy: 253/400 (63.25%), Cohen's Kappa: 0.4862, QWK Score: 0.8059, F1-Score: 0.4655, Specificity: 0.9028
# QWK did not improved from 0.8364
# ----------------------------------------Epoch: 11----------------------------------------
#  [=======================================>]  Step: 337ms | Tot: 24s746ms | loss: 0.3127 | tra 75/75
#
# Train set: Average loss: 0.5002, Cohen's Kappa: 0.5623, QWK Score: 0.8778, Accuracy: (69.42%), F1-Score: 0.5026, Specificity: 0.9176
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 501ms | Tot: 5s310ms | test 25/25 ====================>...................]  Step: 189ms | Tot: 2s841ms | test 14/25
#
# Test set: Average loss: 0.0877, Accuracy: 270/400 (67.50%), Cohen's Kappa: 0.5341, QWK Score: 0.8255, F1-Score: 0.4918, Specificity: 0.9100
# QWK did not improved from 0.8364
# ----------------------------------------Epoch: 12----------------------------------------
#  [=======================================>]  Step: 325ms | Tot: 24s710ms | loss: 0.2381 | tra 75/75
#
# Train set: Average loss: 0.4765, Cohen's Kappa: 0.5914, QWK Score: 0.8825, Accuracy: (71.42%), F1-Score: 0.5225, Specificity: 0.9230
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 543ms | Tot: 5s273ms | test 25/25 ===>...................................]  Step: 64ms | Tot: 205ms | test    4/25 ===========>............................]  Step: 64ms | Tot: 1s72ms | test   8/25 =================>......................]  Step: 65ms | Tot: 1s946ms | test  12/25 ==============================>.........]  Step: 65ms | Tot: 3s818ms | test  20/25 ===================================>....]  Step: 79ms | Tot: 4s667ms | test  23/25
#
# Test set: Average loss: 0.0881, Accuracy: 261/400 (65.25%), Cohen's Kappa: 0.5106, QWK Score: 0.8323, F1-Score: 0.4723, Specificity: 0.9073
# QWK did not improved from 0.8364
# ----------------------------------------Epoch: 13----------------------------------------
#  [=======================================>]  Step: 318ms | Tot: 24s636ms | loss: 0.7468 | tra 75/75
#
# Train set: Average loss: 0.4649, Cohen's Kappa: 0.5916, QWK Score: 0.8822, Accuracy: (71.33%), F1-Score: 0.5193, Specificity: 0.9243
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 401ms | Tot: 5s245ms | test 25/25 ==>....................................]  Step: 65ms | Tot: 211ms | test    3/25
#
# Test set: Average loss: 0.0896, Accuracy: 274/400 (68.50%), Cohen's Kappa: 0.5492, QWK Score: 0.7955, F1-Score: 0.5092, Specificity: 0.9127
# QWK did not improved from 0.8364
# ----------------------------------------Epoch: 14----------------------------------------
#  [=======================================>]  Step: 328ms | Tot: 24s661ms | loss: 0.2681 | tra 75/75
#
# Train set: Average loss: 0.4128, Cohen's Kappa: 0.6325, QWK Score: 0.8962, Accuracy: (74.42%), F1-Score: 0.5465, Specificity: 0.9309
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 468ms | Tot: 5s273ms | test 25/25 =============>.........................]  Step: 179ms | Tot: 1s911ms | test 10/25 =================================>......]  Step: 197ms | Tot: 4s664ms | test 22/25
#
# Test set: Average loss: 0.0935, Accuracy: 258/400 (64.50%), Cohen's Kappa: 0.4897, QWK Score: 0.7919, F1-Score: 0.4526, Specificity: 0.9010
# QWK did not improved from 0.8364
# ----------------------------------------Epoch: 15----------------------------------------
#  [=======================================>]  Step: 316ms | Tot: 24s726ms | loss: 0.4933 | tra 75/75
#
# Train set: Average loss: 0.4099, Cohen's Kappa: 0.6436, QWK Score: 0.8939, Accuracy: (75.25%), F1-Score: 0.5517, Specificity: 0.9330
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 467ms | Tot: 5s272ms | test 25/25 ==>....................................]  Step: 111ms | Tot: 220ms | test   3/25 ====>...................................]  Step: 63ms | Tot: 283ms | test    4/25 =========>..............................]  Step: 64ms | Tot: 1s70ms | test   7/25 ====================================>...]  Step: 62ms | Tot: 4s805ms | test  24/25
#
# Test set: Average loss: 0.0915, Accuracy: 235/400 (58.75%), Cohen's Kappa: 0.4477, QWK Score: 0.7682, F1-Score: 0.4634, Specificity: 0.8961
# QWK did not improved from 0.8364
# ----------------------------------------Epoch: 16----------------------------------------
#  [=======================================>]  Step: 329ms | Tot: 24s550ms | loss: 0.4464 | tra 75/75
#
# Train set: Average loss: 0.4244, Cohen's Kappa: 0.6388, QWK Score: 0.8929, Accuracy: (74.58%), F1-Score: 0.5602, Specificity: 0.9332
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 506ms | Tot: 5s235ms | test 25/25 ==========>............................]  Step: 62ms | Tot: 1s77ms | test   8/25 ============================>...........]  Step: 67ms | Tot: 3s710ms | test  19/25
#
# Test set: Average loss: 0.0907, Accuracy: 271/400 (67.75%), Cohen's Kappa: 0.5469, QWK Score: 0.8027, F1-Score: 0.5131, Specificity: 0.9130
# QWK did not improved from 0.8364
# ----------------------------------------Epoch: 17----------------------------------------
#  [=======================================>]  Step: 322ms | Tot: 24s596ms | loss: 0.1880 | tra 75/75
#
# Train set: Average loss: 0.3683, Cohen's Kappa: 0.6633, QWK Score: 0.9111, Accuracy: (76.42%), F1-Score: 0.5846, Specificity: 0.9375
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 547ms | Tot: 5s315ms | test 25/25 ========>..............................]  Step: 62ms | Tot: 1s59ms | test   7/25 ====================>...................]  Step: 203ms | Tot: 2s820ms | test 14/25 ===================================>....]  Step: 62ms | Tot: 4s704ms | test  23/25
#
# Test set: Average loss: 0.0912, Accuracy: 272/400 (68.00%), Cohen's Kappa: 0.5519, QWK Score: 0.8018, F1-Score: 0.5134, Specificity: 0.9150
# QWK did not improved from 0.8364
# ----------------------------------------Epoch: 18----------------------------------------
#  [=======================================>]  Step: 314ms | Tot: 24s487ms | loss: 0.3057 | tra 75/75
#
# Train set: Average loss: 0.3533, Cohen's Kappa: 0.6864, QWK Score: 0.9125, Accuracy: (78.00%), F1-Score: 0.6530, Specificity: 0.9414
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 413ms | Tot: 5s247ms | test 25/25 =============>.........................]  Step: 191ms | Tot: 1s894ms | test 10/25
#
# Test set: Average loss: 0.0906, Accuracy: 260/400 (65.00%), Cohen's Kappa: 0.5112, QWK Score: 0.8270, F1-Score: 0.5519, Specificity: 0.9081
# QWK did not improved from 0.8364
# ----------------------------------------Epoch: 19----------------------------------------
#  [=======================================>]  Step: 325ms | Tot: 24s641ms | loss: 0.1701 | tra 75/75
#
# Train set: Average loss: 0.3749, Cohen's Kappa: 0.6712, QWK Score: 0.9128, Accuracy: (77.00%), F1-Score: 0.6616, Specificity: 0.9379
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 582ms | Tot: 5s298ms | test 25/25 ===>...................................]  Step: 65ms | Tot: 200ms | test    4/25 ===========>............................]  Step: 66ms | Tot: 1s65ms | test   8/25 =================>......................]  Step: 63ms | Tot: 1s931ms | test  12/25 ====================================>...]  Step: 63ms | Tot: 4s716ms | test  24/25
#
# Test set: Average loss: 0.0902, Accuracy: 274/400 (68.50%), Cohen's Kappa: 0.5589, QWK Score: 0.8067, F1-Score: 0.5936, Specificity: 0.9151
# QWK did not improved from 0.8364
# ----------------------------------------Epoch: 20----------------------------------------
#  [=======================================>]  Step: 358ms | Tot: 31s142ms | loss: 0.1877 | tra 75/75
#
# Train set: Average loss: 0.3611, Cohen's Kappa: 0.7094, QWK Score: 0.8986, Accuracy: (79.42%), F1-Score: 0.7026, Specificity: 0.9454
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 420ms | Tot: 5s690ms | test 25/25 ==>....................................]  Step: 84ms | Tot: 213ms | test    3/25 ==============>.........................]  Step: 201ms | Tot: 2s181ms | test 10/25
#
# Test set: Average loss: 0.0865, Accuracy: 268/400 (67.00%), Cohen's Kappa: 0.5368, QWK Score: 0.8424, F1-Score: 0.5656, Specificity: 0.9119
# Best qwk improved from 0.8364 to 0.8424
# ----------------------------------------Epoch: 21----------------------------------------
#  [=======================================>]  Step: 345ms | Tot: 26s566ms | loss: 0.4252 | tra 75/75
#
# Train set: Average loss: 0.3368, Cohen's Kappa: 0.7262, QWK Score: 0.9189, Accuracy: (80.58%), F1-Score: 0.7465, Specificity: 0.9487
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 433ms | Tot: 5s354ms | test 25/25 ===========================>............]  Step: 191ms | Tot: 3s791ms | test 18/25 =================================>......]  Step: 194ms | Tot: 4s730ms | test 22/25 ====================================>...]  Step: 65ms | Tot: 4s920ms | test  24/25
#
# Test set: Average loss: 0.0936, Accuracy: 268/400 (67.00%), Cohen's Kappa: 0.5276, QWK Score: 0.7830, F1-Score: 0.5661, Specificity: 0.9078
# QWK did not improved from 0.8424
# ----------------------------------------Epoch: 22----------------------------------------
#  [=======================================>]  Step: 335ms | Tot: 26s537ms | loss: 0.4855 | tra 75/75
#
# Train set: Average loss: 0.3363, Cohen's Kappa: 0.7311, QWK Score: 0.9190, Accuracy: (80.92%), F1-Score: 0.7368, Specificity: 0.9506
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 511ms | Tot: 5s425ms | test 25/25 ===>...................................]  Step: 66ms | Tot: 210ms | test    4/25 ======================>.................]  Step: 79ms | Tot: 2s896ms | test  15/25
#
# Test set: Average loss: 0.0894, Accuracy: 262/400 (65.50%), Cohen's Kappa: 0.5205, QWK Score: 0.8278, F1-Score: 0.5744, Specificity: 0.9094
# QWK did not improved from 0.8424
# ----------------------------------------Epoch: 23----------------------------------------
#  [=======================================>]  Step: 341ms | Tot: 26s749ms | loss: 0.2968 | tra 75/75
#
# Train set: Average loss: 0.2883, Cohen's Kappa: 0.7735, QWK Score: 0.9315, Accuracy: (83.92%), F1-Score: 0.7803, Specificity: 0.9583
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 455ms | Tot: 5s398ms | test 25/25 =======>...............................]  Step: 192ms | Tot: 1s62ms | test  6/25 ==============>.........................]  Step: 184ms | Tot: 1s926ms | test 10/25 ==============================>.........]  Step: 69ms | Tot: 4s12ms | test   20/25
#
# Test set: Average loss: 0.0893, Accuracy: 262/400 (65.50%), Cohen's Kappa: 0.5246, QWK Score: 0.8088, F1-Score: 0.5580, Specificity: 0.9107
# QWK did not improved from 0.8424
# ----------------------------------------Epoch: 24----------------------------------------
#  [=======================================>]  Step: 330ms | Tot: 26s509ms | loss: 0.8101 | tra 75/75
#
# Train set: Average loss: 0.3336, Cohen's Kappa: 0.7443, QWK Score: 0.9193, Accuracy: (81.75%), F1-Score: 0.7620, Specificity: 0.9537
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 561ms | Tot: 5s349ms | test 25/25 ==============================>.........]  Step: 125ms | Tot: 3s857ms | test 20/25 ===================================>....]  Step: 65ms | Tot: 4s716ms | test  23/25
#
# Test set: Average loss: 0.0937, Accuracy: 259/400 (64.75%), Cohen's Kappa: 0.4980, QWK Score: 0.8000, F1-Score: 0.5415, Specificity: 0.9030
# QWK did not improved from 0.8424
# ----------------------------------------Epoch: 25----------------------------------------
#  [=======================================>]  Step: 376ms | Tot: 25s764ms | loss: 0.2273 | tra 75/75
#
# Train set: Average loss: 0.2948, Cohen's Kappa: 0.7585, QWK Score: 0.9365, Accuracy: (83.00%), F1-Score: 0.7682, Specificity: 0.9544
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 482ms | Tot: 5s510ms | test 25/25 ================>.......................]  Step: 68ms | Tot: 1s932ms | test  11/25
#
# Test set: Average loss: 0.0929, Accuracy: 269/400 (67.25%), Cohen's Kappa: 0.5375, QWK Score: 0.8187, F1-Score: 0.5658, Specificity: 0.9113
# QWK did not improved from 0.8424
# ----------------------------------------Epoch: 26----------------------------------------
#  [=======================================>]  Step: 333ms | Tot: 25s555ms | loss: 0.0748 | tra 75/75
#
# Train set: Average loss: 0.3258, Cohen's Kappa: 0.7631, QWK Score: 0.9188, Accuracy: (83.25%), F1-Score: 0.7811, Specificity: 0.9552
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 509ms | Tot: 5s398ms | test 25/25 ==========>............................]  Step: 65ms | Tot: 1s73ms | test   8/25 =================>......................]  Step: 67ms | Tot: 1s986ms | test  12/25 ======================>.................]  Step: 87ms | Tot: 2s856ms | test  15/25 ==============================>.........]  Step: 74ms | Tot: 3s932ms | test  20/25 ====================================>...]  Step: 71ms | Tot: 4s888ms | test  24/25
#
# Test set: Average loss: 0.0883, Accuracy: 272/400 (68.00%), Cohen's Kappa: 0.5594, QWK Score: 0.8391, F1-Score: 0.6218, Specificity: 0.9170
# QWK did not improved from 0.8424
# ----------------------------------------Epoch: 27----------------------------------------
#  [==========================>.............]  Step: 350ms | Tot: 17s745ms | loss: 0.3072 | tra 50/75
# ** Ranger21 update = Warmup complete - lr set to 0.001
#
#  [=======================================>]  Step: 336ms | Tot: 26s634ms | loss: 0.2026 | tra 75/75
#
# Train set: Average loss: 0.3190, Cohen's Kappa: 0.7542, QWK Score: 0.9197, Accuracy: (82.58%), F1-Score: 0.7609, Specificity: 0.9544
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 476ms | Tot: 5s436ms | test 25/25 ==============================>.........]  Step: 68ms | Tot: 4s31ms | test   20/25
#
# Test set: Average loss: 0.0950, Accuracy: 270/400 (67.50%), Cohen's Kappa: 0.5334, QWK Score: 0.8093, F1-Score: 0.5750, Specificity: 0.9082
# QWK did not improved from 0.8424
# ----------------------------------------Epoch: 28----------------------------------------
#  [=======================================>]  Step: 338ms | Tot: 26s168ms | loss: 0.1945 | tra 75/75
#
# Train set: Average loss: 0.3343, Cohen's Kappa: 0.7735, QWK Score: 0.9161, Accuracy: (84.08%), F1-Score: 0.7849, Specificity: 0.9562
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 426ms | Tot: 5s364ms | test 25/25 ==>....................................]  Step: 76ms | Tot: 204ms | test    3/25 ==============================>.........]  Step: 68ms | Tot: 3s982ms | test  20/25
#
# Test set: Average loss: 0.0932, Accuracy: 271/400 (67.75%), Cohen's Kappa: 0.5424, QWK Score: 0.8217, F1-Score: 0.5769, Specificity: 0.9122
# QWK did not improved from 0.8424
# ----------------------------------------Epoch: 29----------------------------------------
#  [=======================================>]  Step: 353ms | Tot: 26s478ms | loss: 0.2667 | tra 75/75
#
# Train set: Average loss: 0.2810, Cohen's Kappa: 0.7838, QWK Score: 0.9348, Accuracy: (84.67%), F1-Score: 0.7964, Specificity: 0.9596
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 537ms | Tot: 5s433ms | test 25/25 ===>...................................]  Step: 64ms | Tot: 200ms | test    4/25 ======================>.................]  Step: 67ms | Tot: 2s878ms | test  15/25 ==============================>.........]  Step: 71ms | Tot: 3s946ms | test  20/25
#
# Test set: Average loss: 0.0896, Accuracy: 270/400 (67.50%), Cohen's Kappa: 0.5593, QWK Score: 0.8403, F1-Score: 0.5816, Specificity: 0.9184
# QWK did not improved from 0.8424
# ----------------------------------------Epoch: 30----------------------------------------
#  [=======================================>]  Step: 317ms | Tot: 25s533ms | loss: 0.2573 | tra 75/75
#
# Train set: Average loss: 0.2720, Cohen's Kappa: 0.8037, QWK Score: 0.9360, Accuracy: (86.08%), F1-Score: 0.8152, Specificity: 0.9630
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 561ms | Tot: 5s455ms | test 25/25 ==>....................................]  Step: 121ms | Tot: 183ms | test   3/25 ====>...................................]  Step: 64ms | Tot: 247ms | test    4/25 ===========>............................]  Step: 120ms | Tot: 1s174ms | test 8/25 =================>......................]  Step: 112ms | Tot: 2s78ms | test  12/25 ======================>.................]  Step: 88ms | Tot: 2s889ms | test  15/25 ==============================>.........]  Step: 73ms | Tot: 3s957ms | test  20/25 ===================================>....]  Step: 103ms | Tot: 4s822ms | test 23/25
#
# Test set: Average loss: 0.0945, Accuracy: 267/400 (66.75%), Cohen's Kappa: 0.5349, QWK Score: 0.8017, F1-Score: 0.5687, Specificity: 0.9119
# QWK did not improved from 0.8424
# ----------------------------------------Epoch: 31----------------------------------------
#  [=======================================>]  Step: 340ms | Tot: 25s986ms | loss: 0.3074 | tra 75/75
#
# Train set: Average loss: 0.3201, Cohen's Kappa: 0.7993, QWK Score: 0.9217, Accuracy: (85.75%), F1-Score: 0.8204, Specificity: 0.9621
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 394ms | Tot: 5s278ms | test 25/25 ===>...................................]  Step: 63ms | Tot: 298ms | test    4/25 ===========================>............]  Step: 203ms | Tot: 3s685ms | test 18/25 =================================>......]  Step: 208ms | Tot: 4s656ms | test 22/25
#
# Test set: Average loss: 0.0937, Accuracy: 265/400 (66.25%), Cohen's Kappa: 0.5350, QWK Score: 0.7873, F1-Score: 0.5964, Specificity: 0.9117
# QWK did not improved from 0.8424
# ----------------------------------------Epoch: 32----------------------------------------
#  [=======================================>]  Step: 328ms | Tot: 25s764ms | loss: 0.5398 | tra 75/75
#
# Train set: Average loss: 0.2684, Cohen's Kappa: 0.8132, QWK Score: 0.9346, Accuracy: (86.75%), F1-Score: 0.8193, Specificity: 0.9655
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 433ms | Tot: 5s243ms | test 25/25 =============>.........................]  Step: 209ms | Tot: 1s924ms | test 10/25
#
# Test set: Average loss: 0.0919, Accuracy: 257/400 (64.25%), Cohen's Kappa: 0.5094, QWK Score: 0.7929, F1-Score: 0.5638, Specificity: 0.9075
# QWK did not improved from 0.8424
# ----------------------------------------Epoch: 33----------------------------------------
#  [=======================================>]  Step: 336ms | Tot: 29s29ms | loss: 0.2908 | tra 75/75
#
# Train set: Average loss: 0.2820, Cohen's Kappa: 0.8234, QWK Score: 0.9233, Accuracy: (87.42%), F1-Score: 0.8384, Specificity: 0.9671
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 532ms | Tot: 5s404ms | test 25/25 ==========>............................]  Step: 65ms | Tot: 1s80ms | test   8/25 =================>......................]  Step: 62ms | Tot: 1s946ms | test  12/25 ============================>...........]  Step: 142ms | Tot: 3s829ms | test 19/25
#
# Test set: Average loss: 0.0944, Accuracy: 256/400 (64.00%), Cohen's Kappa: 0.5066, QWK Score: 0.7953, F1-Score: 0.5697, Specificity: 0.9067
# QWK did not improved from 0.8424
# ----------------------------------------Epoch: 34----------------------------------------
#  [=======================================>]  Step: 359ms | Tot: 26s481ms | loss: 0.0731 | tra 75/75
#
# Train set: Average loss: 0.3039, Cohen's Kappa: 0.8189, QWK Score: 0.9201, Accuracy: (87.17%), F1-Score: 0.8361, Specificity: 0.9653
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 424ms | Tot: 5s375ms | test 25/25 ========>..............................]  Step: 66ms | Tot: 1s83ms | test   7/25 ================>.......................]  Step: 67ms | Tot: 1s957ms | test  11/25 ====================>...................]  Step: 205ms | Tot: 2s832ms | test 14/25
#
# Test set: Average loss: 0.0912, Accuracy: 274/400 (68.50%), Cohen's Kappa: 0.5621, QWK Score: 0.8106, F1-Score: 0.6090, Specificity: 0.9174
# QWK did not improved from 0.8424
# ----------------------------------------Epoch: 35----------------------------------------
#  [=======================================>]  Step: 359ms | Tot: 26s346ms | loss: 0.0784 | tra 75/75
#
# Train set: Average loss: 0.2382, Cohen's Kappa: 0.8460, QWK Score: 0.9535, Accuracy: (89.08%), F1-Score: 0.8600, Specificity: 0.9709
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 512ms | Tot: 5s425ms | test 25/25 ===>...................................]  Step: 70ms | Tot: 203ms | test    4/25 ======================>.................]  Step: 71ms | Tot: 2s904ms | test  15/25 ============================>...........]  Step: 77ms | Tot: 3s865ms | test  19/25
#
# Test set: Average loss: 0.0921, Accuracy: 275/400 (68.75%), Cohen's Kappa: 0.5620, QWK Score: 0.7994, F1-Score: 0.6040, Specificity: 0.9156
# QWK did not improved from 0.8424
# No improvement in validation loss for 15 epochs. Early stopping.
# Training time: 00:27:04.76
# Save filename :  HBPASMwithEffv2_ranger21_300circlecrop_normalaug

# %% [markdown]
# # randaug

# %%
IMG_SIZE=300
image_dir = os.path.join('..', 'dataset','ben processed circle crop','deepdridtrain')
trainset = datasets.ImageFolder(image_dir, transform=transforms.Compose([
                                                transforms.Resize((IMG_SIZE, IMG_SIZE), Image.BILINEAR),
                                                augment.RandAugment(),
                                                transforms.ToTensor(),
                                                ]))
trainloader = torch.utils.data.DataLoader(trainset, batch_size=16,
                                          shuffle=True, num_workers=4)

image_dir = os.path.join('..', 'dataset','ben processed circle crop','deepdridvalid')
testset = datasets.ImageFolder(image_dir, transform=transforms.Compose([
                                                transforms.Resize((IMG_SIZE, IMG_SIZE), Image.BILINEAR),
                                                transforms.ToTensor(),
                                                ]))
testloader = torch.utils.data.DataLoader(testset, batch_size=16,
                                         shuffle=False, num_workers=4)
cudnn.benchmark = True
model=optimizermodel.ModelRanger21(filename='HBPASMwithEffv2_ranger21_300circlecrop_randaug',lr=0.001,num_batches_per_epoch=len(trainloader))

df=model.traintest(150,trainloader,testloader)
custom_utils.plot_metrics(df)
custom_utils.plot_confusion_matrix_with_max_qwk(df)
torch.cuda.empty_cache()
# Out:
# Model : HBPASM with EfficientNetv2
# Ranger21 optimizer ready with following settings:
#
# Core optimizer = AdamW
# Learning rate of 0.001
#
# Important - num_epochs of training = ** 150 epochs **
# please confirm this is correct or warmup and warmdown will be off
#
# Warm-up: linear warmup, over 2000 iterations
#
# Lookahead active, merging every 5 steps, with blend factor of 0.5
# Norm Loss active, factor = 0.0001
# Stable weight decay of 0.0001
# Gradient Centralization = On
#
# Adaptive Gradient Clipping = True
# 	clipping value of 0.01
# 	steps for clipping = 0.001
#
# Warm-down: Linear warmdown, starting at 72.0%, iteration 8100 of 11250
# warm down will decay until 3e-05 lr
# ----------------------------------------Epoch: 1----------------------------------------
# params size saved
# total param groups = 1
# total params in groups = 466
#  [=======================================>]  Step: 351ms | Tot: 26s717ms | loss: 2.0171 | tra 75/75
#
# Train set: Average loss: 2.0256, Cohen's Kappa: 0.0032, QWK Score: -0.0100, Accuracy: (30.92%), F1-Score: 0.1671, Specificity: 0.8013
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 437ms | Tot: 5s391ms | test 25/25 ====================>...................]  Step: 193ms | Tot: 2s871ms | test 14/25 =================================>......]  Step: 192ms | Tot: 4s769ms | test 22/25 ====================================>...]  Step: 67ms | Tot: 4s953ms | test  24/25
#
# Test set: Average loss: 0.1259, Accuracy: 174/400 (43.50%), Cohen's Kappa: 0.0000, QWK Score: 0.0000, F1-Score: 0.1213, Specificity: 0.8000
# QWK did not improved from 0.0000
# ----------------------------------------Epoch: 2----------------------------------------
#  [=======================================>]  Step: 397ms | Tot: 26s683ms | loss: 1.9738 | tra 75/75
#
# Train set: Average loss: 1.9943, Cohen's Kappa: 0.0000, QWK Score: 0.0000, Accuracy: (45.00%), F1-Score: 0.1241, Specificity: 0.8000
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 564ms | Tot: 5s818ms | test 25/25 ================>.......................]  Step: 131ms | Tot: 2s175ms | test 11/25 =================>......................]  Step: 69ms | Tot: 2s245ms | test  12/25 ============================>...........]  Step: 200ms | Tot: 4s248ms | test 19/25
#
# Test set: Average loss: 0.1231, Accuracy: 174/400 (43.50%), Cohen's Kappa: 0.0000, QWK Score: 0.0000, F1-Score: 0.1213, Specificity: 0.8000
# QWK did not improved from 0.0000
# ----------------------------------------Epoch: 3----------------------------------------
#  [=======================================>]  Step: 326ms | Tot: 26s370ms | loss: 1.6160 | tra 75/75
#
# Train set: Average loss: 1.8721, Cohen's Kappa: 0.0047, QWK Score: 0.0128, Accuracy: (45.17%), F1-Score: 0.1281, Specificity: 0.8008
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 455ms | Tot: 5s349ms | test 25/25 ================>.......................]  Step: 99ms | Tot: 1s932ms | test  11/25 =================>......................]  Step: 83ms | Tot: 2s16ms | test   12/25 ========================>...............]  Step: 70ms | Tot: 2s948ms | test  16/25 ===========================>............]  Step: 181ms | Tot: 3s745ms | test 18/25 ==============================>.........]  Step: 66ms | Tot: 3s942ms | test  20/25
#
# Test set: Average loss: 0.1147, Accuracy: 205/400 (51.25%), Cohen's Kappa: 0.1868, QWK Score: 0.3659, F1-Score: 0.2367, Specificity: 0.8334
# Best qwk improved from 0.0000 to 0.3659
# ----------------------------------------Epoch: 4----------------------------------------
#  [=======================================>]  Step: 365ms | Tot: 26s845ms | loss: 1.2439 | tra 75/75
#
# Train set: Average loss: 1.4258, Cohen's Kappa: 0.2849, QWK Score: 0.5475, Accuracy: (55.67%), F1-Score: 0.2619, Specificity: 0.8542
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 633ms | Tot: 6s57ms | test  25/25 ========>..............................]  Step: 75ms | Tot: 1s184ms | test  7/25 ==============================>.........]  Step: 78ms | Tot: 4s352ms | test  20/25 ====================================>...]  Step: 73ms | Tot: 5s423ms | test  24/25
#
# Test set: Average loss: 0.1030, Accuracy: 229/400 (57.25%), Cohen's Kappa: 0.3604, QWK Score: 0.7389, F1-Score: 0.2730, Specificity: 0.8744
# Best qwk improved from 0.3659 to 0.7389
# ----------------------------------------Epoch: 5----------------------------------------
#  [=======================================>]  Step: 385ms | Tot: 28s919ms | loss: 1.3514 | tra 75/75
#
# Train set: Average loss: 0.9639, Cohen's Kappa: 0.3811, QWK Score: 0.7543, Accuracy: (59.50%), F1-Score: 0.2804, Specificity: 0.8785
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 553ms | Tot: 6s71ms | test  25/25 ===>...................................]  Step: 104ms | Tot: 258ms | test   4/25 =========>..............................]  Step: 62ms | Tot: 1s178ms | test  7/25 ===========>............................]  Step: 138ms | Tot: 1s317ms | test 8/25 =================>......................]  Step: 151ms | Tot: 2s338ms | test 12/25 ===========================>............]  Step: 186ms | Tot: 4s215ms | test 18/25 ====================================>...]  Step: 102ms | Tot: 5s518ms | test 24/25
#
# Test set: Average loss: 0.0970, Accuracy: 226/400 (56.50%), Cohen's Kappa: 0.3667, QWK Score: 0.7714, F1-Score: 0.2694, Specificity: 0.8791
# Best qwk improved from 0.7389 to 0.7714
# ----------------------------------------Epoch: 6----------------------------------------
#  [=======================================>]  Step: 377ms | Tot: 29s488ms | loss: 0.4193 | tra 75/75
#
# Train set: Average loss: 0.8970, Cohen's Kappa: 0.3677, QWK Score: 0.7265, Accuracy: (58.08%), F1-Score: 0.2765, Specificity: 0.8771
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 542ms | Tot: 6s17ms | test  25/25 ========>..............................]  Step: 75ms | Tot: 1s210ms | test  7/25 ================>.......................]  Step: 73ms | Tot: 2s202ms | test  11/25 ====================>...................]  Step: 194ms | Tot: 3s175ms | test 14/25 ===========================>............]  Step: 193ms | Tot: 4s221ms | test 18/25 ==============================>.........]  Step: 73ms | Tot: 4s413ms | test  20/25
#
# Test set: Average loss: 0.0925, Accuracy: 238/400 (59.50%), Cohen's Kappa: 0.3951, QWK Score: 0.7893, F1-Score: 0.3050, Specificity: 0.8813
# Best qwk improved from 0.7714 to 0.7893
# ----------------------------------------Epoch: 7----------------------------------------
#  [=======================================>]  Step: 360ms | Tot: 27s963ms | loss: 0.3452 | tra 75/75
#
# Train set: Average loss: 0.7534, Cohen's Kappa: 0.4130, QWK Score: 0.7889, Accuracy: (61.08%), F1-Score: 0.3179, Specificity: 0.8860
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 383ms | Tot: 5s768ms | test 25/25 ==>....................................]  Step: 188ms | Tot: 258ms | test   3/25 =========>..............................]  Step: 192ms | Tot: 1s254ms | test 7/25 ====================>...................]  Step: 203ms | Tot: 3s54ms | test  14/25 ===========================>............]  Step: 194ms | Tot: 4s36ms | test  18/25
#
# Test set: Average loss: 0.0911, Accuracy: 251/400 (62.75%), Cohen's Kappa: 0.4430, QWK Score: 0.8125, F1-Score: 0.3553, Specificity: 0.8901
# Best qwk improved from 0.7893 to 0.8125
# ----------------------------------------Epoch: 8----------------------------------------
#  [=======================================>]  Step: 383ms | Tot: 27s619ms | loss: 0.5083 | tra 75/75
#
# Train set: Average loss: 0.6336, Cohen's Kappa: 0.4731, QWK Score: 0.8353, Accuracy: (64.67%), F1-Score: 0.3782, Specificity: 0.8987
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 513ms | Tot: 5s888ms | test 25/25 =============>.........................]  Step: 185ms | Tot: 2s74ms | test  10/25 ====================>...................]  Step: 186ms | Tot: 3s50ms | test  14/25 =================================>......]  Step: 180ms | Tot: 5s169ms | test 22/25 ====================================>...]  Step: 69ms | Tot: 5s374ms | test  24/25
#
# Test set: Average loss: 0.0877, Accuracy: 262/400 (65.50%), Cohen's Kappa: 0.4983, QWK Score: 0.8398, F1-Score: 0.4269, Specificity: 0.9024
# Best qwk improved from 0.8125 to 0.8398
# ----------------------------------------Epoch: 9----------------------------------------
#  [=======================================>]  Step: 368ms | Tot: 27s761ms | loss: 0.4819 | tra 75/75
#
# Train set: Average loss: 0.5575, Cohen's Kappa: 0.5017, QWK Score: 0.8620, Accuracy: (66.00%), F1-Score: 0.4277, Specificity: 0.9052
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 533ms | Tot: 5s812ms | test 25/25 =================>......................]  Step: 122ms | Tot: 2s195ms | test 12/25
#
# Test set: Average loss: 0.0881, Accuracy: 260/400 (65.00%), Cohen's Kappa: 0.4961, QWK Score: 0.8336, F1-Score: 0.4379, Specificity: 0.9026
# QWK did not improved from 0.8398
# ----------------------------------------Epoch: 10----------------------------------------
#  [=======================================>]  Step: 371ms | Tot: 27s455ms | loss: 0.7354 | tra 75/75
#
# Train set: Average loss: 0.5337, Cohen's Kappa: 0.5596, QWK Score: 0.8692, Accuracy: (69.67%), F1-Score: 0.4799, Specificity: 0.9167
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 553ms | Tot: 5s730ms | test 25/25 ==>....................................]  Step: 106ms | Tot: 193ms | test   3/25 ====>...................................]  Step: 76ms | Tot: 269ms | test    4/25 =========>..............................]  Step: 80ms | Tot: 1s107ms | test  7/25 ============================>...........]  Step: 195ms | Tot: 4s123ms | test 19/25 ===================================>....]  Step: 184ms | Tot: 5s108ms | test 23/25
#
# Test set: Average loss: 0.0889, Accuracy: 263/400 (65.75%), Cohen's Kappa: 0.5093, QWK Score: 0.8036, F1-Score: 0.4721, Specificity: 0.9048
# QWK did not improved from 0.8398
# ----------------------------------------Epoch: 11----------------------------------------
#  [=======================================>]  Step: 331ms | Tot: 26s652ms | loss: 0.3440 | tra 75/75
#
# Train set: Average loss: 0.4635, Cohen's Kappa: 0.6014, QWK Score: 0.8952, Accuracy: (72.58%), F1-Score: 0.5146, Specificity: 0.9241
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 385ms | Tot: 5s153ms | test 25/25 ================>.......................]  Step: 180ms | Tot: 1s972ms | test 11/25 ===================================>....]  Step: 178ms | Tot: 4s707ms | test 23/25
#
# Test set: Average loss: 0.0897, Accuracy: 260/400 (65.00%), Cohen's Kappa: 0.5063, QWK Score: 0.8042, F1-Score: 0.4650, Specificity: 0.9063
# QWK did not improved from 0.8398
# ----------------------------------------Epoch: 12----------------------------------------
#  [=======================================>]  Step: 338ms | Tot: 24s432ms | loss: 0.2339 | tra 75/75
#
# Train set: Average loss: 0.4178, Cohen's Kappa: 0.6246, QWK Score: 0.9011, Accuracy: (73.92%), F1-Score: 0.5352, Specificity: 0.9303
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 406ms | Tot: 5s212ms | test 25/25 ===>...................................]  Step: 62ms | Tot: 303ms | test    4/25 ===========>............................]  Step: 64ms | Tot: 1s157ms | test  8/25 =================>......................]  Step: 63ms | Tot: 2s21ms | test   12/25 ====================>...................]  Step: 188ms | Tot: 2s725ms | test 14/25 ===========================>............]  Step: 206ms | Tot: 3s671ms | test 18/25
#
# Test set: Average loss: 0.0927, Accuracy: 257/400 (64.25%), Cohen's Kappa: 0.4894, QWK Score: 0.7833, F1-Score: 0.4622, Specificity: 0.9028
# QWK did not improved from 0.8398
# ----------------------------------------Epoch: 13----------------------------------------
#  [=======================================>]  Step: 351ms | Tot: 24s568ms | loss: 0.4201 | tra 75/75
#
# Train set: Average loss: 0.3651, Cohen's Kappa: 0.6515, QWK Score: 0.9152, Accuracy: (75.92%), F1-Score: 0.5514, Specificity: 0.9344
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 425ms | Tot: 5s143ms | test 25/25 ===>...................................]  Step: 115ms | Tot: 289ms | test   4/25 =================>......................]  Step: 123ms | Tot: 2s22ms | test  12/25 ====================>...................]  Step: 213ms | Tot: 2s736ms | test 14/25
#
# Test set: Average loss: 0.0894, Accuracy: 259/400 (64.75%), Cohen's Kappa: 0.5121, QWK Score: 0.8267, F1-Score: 0.4818, Specificity: 0.9088
# QWK did not improved from 0.8398
# ----------------------------------------Epoch: 14----------------------------------------
#  [=======================================>]  Step: 322ms | Tot: 24s555ms | loss: 0.4138 | tra 75/75
#
# Train set: Average loss: 0.3824, Cohen's Kappa: 0.6307, QWK Score: 0.9084, Accuracy: (74.17%), F1-Score: 0.5463, Specificity: 0.9318
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 463ms | Tot: 5s124ms | test 25/25 ====================>...................]  Step: 203ms | Tot: 2s711ms | test 14/25 ===========================>............]  Step: 193ms | Tot: 3s634ms | test 18/25 =================================>......]  Step: 195ms | Tot: 4s536ms | test 22/25
#
# Test set: Average loss: 0.0923, Accuracy: 260/400 (65.00%), Cohen's Kappa: 0.5035, QWK Score: 0.7875, F1-Score: 0.4806, Specificity: 0.9050
# QWK did not improved from 0.8398
# ----------------------------------------Epoch: 15----------------------------------------
#  [=======================================>]  Step: 330ms | Tot: 24s417ms | loss: 0.6665 | tra 75/75
#
# Train set: Average loss: 0.4192, Cohen's Kappa: 0.6180, QWK Score: 0.8953, Accuracy: (73.50%), F1-Score: 0.5279, Specificity: 0.9286
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 603ms | Tot: 5s185ms | test 25/25 ===>...................................]  Step: 60ms | Tot: 188ms | test    4/25 ===========>............................]  Step: 62ms | Tot: 1s56ms | test   8/25 ==============================>.........]  Step: 73ms | Tot: 3s696ms | test  20/25 ====================================>...]  Step: 61ms | Tot: 4s581ms | test  24/25
#
# Test set: Average loss: 0.0903, Accuracy: 256/400 (64.00%), Cohen's Kappa: 0.4912, QWK Score: 0.8021, F1-Score: 0.4648, Specificity: 0.9030
# QWK did not improved from 0.8398
# ----------------------------------------Epoch: 16----------------------------------------
#  [=======================================>]  Step: 333ms | Tot: 24s567ms | loss: 0.2320 | tra 75/75
#
# Train set: Average loss: 0.3554, Cohen's Kappa: 0.6607, QWK Score: 0.9107, Accuracy: (76.17%), F1-Score: 0.5841, Specificity: 0.9377
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 425ms | Tot: 5s111ms | test 25/25 ===========================>............]  Step: 174ms | Tot: 3s595ms | test 18/25 ==============================>.........]  Step: 61ms | Tot: 3s788ms | test  20/25 =================================>......]  Step: 182ms | Tot: 4s489ms | test 22/25 ====================================>...]  Step: 62ms | Tot: 4s685ms | test  24/25
#
# Test set: Average loss: 0.0894, Accuracy: 263/400 (65.75%), Cohen's Kappa: 0.5359, QWK Score: 0.8291, F1-Score: 0.5836, Specificity: 0.9133
# QWK did not improved from 0.8398
# ----------------------------------------Epoch: 17----------------------------------------
#  [=======================================>]  Step: 344ms | Tot: 24s557ms | loss: 0.3444 | tra 75/75
#
# Train set: Average loss: 0.2903, Cohen's Kappa: 0.7238, QWK Score: 0.9348, Accuracy: (80.58%), F1-Score: 0.7014, Specificity: 0.9493
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 446ms | Tot: 5s124ms | test 25/25 ===>...................................]  Step: 65ms | Tot: 192ms | test    4/25 =========>..............................]  Step: 61ms | Tot: 1s38ms | test   7/25 ====================>...................]  Step: 198ms | Tot: 2s723ms | test 14/25 ===========================>............]  Step: 198ms | Tot: 3s632ms | test 18/25
#
# Test set: Average loss: 0.0876, Accuracy: 269/400 (67.25%), Cohen's Kappa: 0.5399, QWK Score: 0.8429, F1-Score: 0.5510, Specificity: 0.9119
# Best qwk improved from 0.8398 to 0.8429
# ----------------------------------------Epoch: 18----------------------------------------
#  [=======================================>]  Step: 327ms | Tot: 25s290ms | loss: 0.2737 | tra 75/75
#
# Train set: Average loss: 0.2620, Cohen's Kappa: 0.7681, QWK Score: 0.9410, Accuracy: (83.58%), F1-Score: 0.7609, Specificity: 0.9573
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 505ms | Tot: 5s430ms | test 25/25
#
# Test set: Average loss: 0.0874, Accuracy: 242/400 (60.50%), Cohen's Kappa: 0.4742, QWK Score: 0.8056, F1-Score: 0.5432, Specificity: 0.9023
# QWK did not improved from 0.8429
# ----------------------------------------Epoch: 19----------------------------------------
#  [=======================================>]  Step: 355ms | Tot: 25s751ms | loss: 0.1943 | tra 75/75
#
# Train set: Average loss: 0.2810, Cohen's Kappa: 0.7700, QWK Score: 0.9380, Accuracy: (83.67%), F1-Score: 0.7727, Specificity: 0.9579
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 419ms | Tot: 5s286ms | test 25/25 ================>.......................]  Step: 80ms | Tot: 1s959ms | test  11/25 ========================>...............]  Step: 63ms | Tot: 2s965ms | test  16/25 =================================>......]  Step: 195ms | Tot: 4s644ms | test 22/25
#
# Test set: Average loss: 0.0938, Accuracy: 255/400 (63.75%), Cohen's Kappa: 0.4859, QWK Score: 0.7772, F1-Score: 0.5003, Specificity: 0.9014
# QWK did not improved from 0.8429
# ----------------------------------------Epoch: 20----------------------------------------
#  [=======================================>]  Step: 361ms | Tot: 26s243ms | loss: 0.1104 | tra 75/75
#
# Train set: Average loss: 0.2866, Cohen's Kappa: 0.7651, QWK Score: 0.9405, Accuracy: (83.25%), F1-Score: 0.7692, Specificity: 0.9573
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 560ms | Tot: 5s635ms | test 25/25 ================>.......................]  Step: 73ms | Tot: 1s989ms | test  11/25
#
# Test set: Average loss: 0.0909, Accuracy: 268/400 (67.00%), Cohen's Kappa: 0.5406, QWK Score: 0.8253, F1-Score: 0.5760, Specificity: 0.9126
# QWK did not improved from 0.8429
# ----------------------------------------Epoch: 21----------------------------------------
#  [=======================================>]  Step: 397ms | Tot: 28s928ms | loss: 0.1434 | tra 75/75
#
# Train set: Average loss: 0.2604, Cohen's Kappa: 0.8042, QWK Score: 0.9351, Accuracy: (86.00%), F1-Score: 0.8119, Specificity: 0.9649
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 494ms | Tot: 6s46ms | test  25/25 =======>...............................]  Step: 195ms | Tot: 1s189ms | test 6/25 ==============>.........................]  Step: 204ms | Tot: 2s193ms | test 10/25
#
# Test set: Average loss: 0.0921, Accuracy: 268/400 (67.00%), Cohen's Kappa: 0.5334, QWK Score: 0.8295, F1-Score: 0.5599, Specificity: 0.9103
# QWK did not improved from 0.8429
# ----------------------------------------Epoch: 22----------------------------------------
#  [=======================================>]  Step: 359ms | Tot: 28s589ms | loss: 0.3343 | tra 75/75
#
# Train set: Average loss: 0.2309, Cohen's Kappa: 0.8252, QWK Score: 0.9508, Accuracy: (87.58%), F1-Score: 0.8320, Specificity: 0.9682
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 437ms | Tot: 6s269ms | test 25/25 =============>.........................]  Step: 181ms | Tot: 2s171ms | test 10/25 ====================================>...]  Step: 71ms | Tot: 5s831ms | test  24/25
#
# Test set: Average loss: 0.0981, Accuracy: 257/400 (64.25%), Cohen's Kappa: 0.4963, QWK Score: 0.7934, F1-Score: 0.5449, Specificity: 0.9018
# QWK did not improved from 0.8429
# ----------------------------------------Epoch: 23----------------------------------------
#  [=======================================>]  Step: 384ms | Tot: 29s442ms | loss: 0.2622 | tra 75/75
#
# Train set: Average loss: 0.2440, Cohen's Kappa: 0.8306, QWK Score: 0.9373, Accuracy: (88.00%), F1-Score: 0.8429, Specificity: 0.9685
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 550ms | Tot: 6s639ms | test 25/25 ===>...................................]  Step: 91ms | Tot: 352ms | test    4/25 =========>..............................]  Step: 73ms | Tot: 1s351ms | test  7/25 ==============================>.........]  Step: 80ms | Tot: 4s919ms | test  20/25 =================================>......]  Step: 200ms | Tot: 5s913ms | test 22/25
#
# Test set: Average loss: 0.0999, Accuracy: 235/400 (58.75%), Cohen's Kappa: 0.4388, QWK Score: 0.7891, F1-Score: 0.4889, Specificity: 0.8933
# QWK did not improved from 0.8429
# ----------------------------------------Epoch: 24----------------------------------------
#  [=======================================>]  Step: 372ms | Tot: 28s973ms | loss: 0.2771 | tra 75/75
#
# Train set: Average loss: 0.2965, Cohen's Kappa: 0.8128, QWK Score: 0.9194, Accuracy: (86.67%), F1-Score: 0.8299, Specificity: 0.9653
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 486ms | Tot: 5s779ms | test 25/25 ==>....................................]  Step: 112ms | Tot: 186ms | test   3/25 ====>...................................]  Step: 70ms | Tot: 257ms | test    4/25 ===========>............................]  Step: 79ms | Tot: 1s192ms | test  8/25 ======================>.................]  Step: 178ms | Tot: 3s130ms | test 15/25
#
# Test set: Average loss: 0.1015, Accuracy: 252/400 (63.00%), Cohen's Kappa: 0.4748, QWK Score: 0.7395, F1-Score: 0.5282, Specificity: 0.8970
# QWK did not improved from 0.8429
# ----------------------------------------Epoch: 25----------------------------------------
#  [=======================================>]  Step: 357ms | Tot: 26s966ms | loss: 0.2768 | tra 75/75
#
# Train set: Average loss: 0.3270, Cohen's Kappa: 0.7942, QWK Score: 0.9150, Accuracy: (85.33%), F1-Score: 0.8083, Specificity: 0.9625
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 426ms | Tot: 5s743ms | test 25/25 ===>...................................]  Step: 116ms | Tot: 270ms | test   4/25 =================>......................]  Step: 186ms | Tot: 2s171ms | test 12/25 ========================>...............]  Step: 201ms | Tot: 3s187ms | test 16/25
#
# Test set: Average loss: 0.0997, Accuracy: 254/400 (63.50%), Cohen's Kappa: 0.4995, QWK Score: 0.7902, F1-Score: 0.5644, Specificity: 0.9052
# QWK did not improved from 0.8429
# ----------------------------------------Epoch: 26----------------------------------------
#  [=======================================>]  Step: 317ms | Tot: 29s40ms | loss: 0.1413 | tra 75/75
#
# Train set: Average loss: 0.2485, Cohen's Kappa: 0.8384, QWK Score: 0.9400, Accuracy: (88.50%), F1-Score: 0.8463, Specificity: 0.9704
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 565ms | Tot: 6s243ms | test 25/25 ==>....................................]  Step: 118ms | Tot: 183ms | test   3/25 ====>...................................]  Step: 75ms | Tot: 258ms | test    4/25 ===========>............................]  Step: 58ms | Tot: 1s300ms | test  8/25
#
# Test set: Average loss: 0.0961, Accuracy: 264/400 (66.00%), Cohen's Kappa: 0.5183, QWK Score: 0.8105, F1-Score: 0.5379, Specificity: 0.9072
# QWK did not improved from 0.8429
# ----------------------------------------Epoch: 27----------------------------------------
#  [==========================>.............]  Step: 400ms | Tot: 18s642ms | loss: 0.1396 | tra 50/75
# ** Ranger21 update = Warmup complete - lr set to 0.001
#
#  [=======================================>]  Step: 343ms | Tot: 28s56ms | loss: 0.2189 | tra 75/75
#
# Train set: Average loss: 0.2519, Cohen's Kappa: 0.8250, QWK Score: 0.9412, Accuracy: (87.58%), F1-Score: 0.8368, Specificity: 0.9674
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 473ms | Tot: 6s71ms | test  25/25 ==>....................................]  Step: 96ms | Tot: 212ms | test    3/25 ====>...................................]  Step: 108ms | Tot: 321ms | test   4/25 ===========>............................]  Step: 130ms | Tot: 1s366ms | test 8/25 ============================>...........]  Step: 179ms | Tot: 4s452ms | test 19/25
#
# Test set: Average loss: 0.0953, Accuracy: 256/400 (64.00%), Cohen's Kappa: 0.4918, QWK Score: 0.7873, F1-Score: 0.5372, Specificity: 0.9015
# QWK did not improved from 0.8429
# ----------------------------------------Epoch: 28----------------------------------------
#  [=======================================>]  Step: 339ms | Tot: 27s348ms | loss: 0.1101 | tra 75/75
#
# Train set: Average loss: 0.2233, Cohen's Kappa: 0.8632, QWK Score: 0.9592, Accuracy: (90.25%), F1-Score: 0.8756, Specificity: 0.9753
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 540ms | Tot: 6s14ms | test  25/25
#
# Test set: Average loss: 0.0960, Accuracy: 261/400 (65.25%), Cohen's Kappa: 0.5275, QWK Score: 0.8201, F1-Score: 0.5826, Specificity: 0.9110
# QWK did not improved from 0.8429
# ----------------------------------------Epoch: 29----------------------------------------
#  [=======================================>]  Step: 368ms | Tot: 28s40ms | loss: 0.1940 | tra 75/75
#
# Train set: Average loss: 0.3021, Cohen's Kappa: 0.8520, QWK Score: 0.9261, Accuracy: (89.50%), F1-Score: 0.8506, Specificity: 0.9729
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 493ms | Tot: 5s704ms | test 25/25 ==>....................................]  Step: 115ms | Tot: 183ms | test   3/25 ====>...................................]  Step: 84ms | Tot: 268ms | test    4/25 =========>..............................]  Step: 75ms | Tot: 1s154ms | test  7/25 ======================>.................]  Step: 193ms | Tot: 3s116ms | test 15/25 ===================================>....]  Step: 205ms | Tot: 5s138ms | test 23/25
#
# Test set: Average loss: 0.0943, Accuracy: 254/400 (63.50%), Cohen's Kappa: 0.4980, QWK Score: 0.8120, F1-Score: 0.5217, Specificity: 0.9055
# QWK did not improved from 0.8429
# ----------------------------------------Epoch: 30----------------------------------------
#  [=======================================>]  Step: 353ms | Tot: 27s548ms | loss: 0.1394 | tra 75/75
#
# Train set: Average loss: 0.2283, Cohen's Kappa: 0.8499, QWK Score: 0.9502, Accuracy: (89.33%), F1-Score: 0.8564, Specificity: 0.9725
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 465ms | Tot: 5s698ms | test 25/25
#
# Test set: Average loss: 0.0943, Accuracy: 259/400 (64.75%), Cohen's Kappa: 0.5075, QWK Score: 0.8117, F1-Score: 0.5569, Specificity: 0.9059
# QWK did not improved from 0.8429
# ----------------------------------------Epoch: 31----------------------------------------
#  [=======================================>]  Step: 344ms | Tot: 29s295ms | loss: 0.1356 | tra 75/75
#
# Train set: Average loss: 0.2409, Cohen's Kappa: 0.8633, QWK Score: 0.9520, Accuracy: (90.25%), F1-Score: 0.8818, Specificity: 0.9751
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 482ms | Tot: 5s759ms | test 25/25 ===========================>............]  Step: 206ms | Tot: 4s19ms | test  18/25
#
# Test set: Average loss: 0.1015, Accuracy: 237/400 (59.25%), Cohen's Kappa: 0.4264, QWK Score: 0.7384, F1-Score: 0.4955, Specificity: 0.8897
# QWK did not improved from 0.8429
# ----------------------------------------Epoch: 32----------------------------------------
#  [=======================================>]  Step: 352ms | Tot: 26s309ms | loss: 0.2023 | tra 75/75
#
# Train set: Average loss: 0.2395, Cohen's Kappa: 0.8580, QWK Score: 0.9492, Accuracy: (89.92%), F1-Score: 0.8758, Specificity: 0.9736
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 590ms | Tot: 5s563ms | test 25/25 ==========>............................]  Step: 64ms | Tot: 1s185ms | test  8/25 =================>......................]  Step: 68ms | Tot: 2s100ms | test  12/25
#
# Test set: Average loss: 0.0932, Accuracy: 248/400 (62.00%), Cohen's Kappa: 0.4764, QWK Score: 0.8173, F1-Score: 0.5346, Specificity: 0.9009
# QWK did not improved from 0.8429
# No improvement in validation loss for 15 epochs. Early stopping.
# Training time: 00:23:21.21
# Save filename :  HBPASMwithEffv2_ranger21_300circlecrop_randaug

# %% [markdown]
# # trivial augment

# %%
IMG_SIZE=300
image_dir = os.path.join('..', 'dataset','ben processed circle crop','deepdridtrain')
trainset = datasets.ImageFolder(image_dir, transform=transforms.Compose([
                                                transforms.Resize((IMG_SIZE, IMG_SIZE), Image.BILINEAR),
                                                augment.TrivialAugmentWide(),
                                                transforms.ToTensor(),
                                                ]))
trainloader = torch.utils.data.DataLoader(trainset, batch_size=16,
                                          shuffle=True, num_workers=4)

image_dir = os.path.join('..', 'dataset','ben processed circle crop','deepdridvalid')
testset = datasets.ImageFolder(image_dir, transform=transforms.Compose([
                                                transforms.Resize((IMG_SIZE, IMG_SIZE), Image.BILINEAR),
                                                transforms.ToTensor(),
                                                ]))
testloader = torch.utils.data.DataLoader(testset, batch_size=16,
                                         shuffle=False, num_workers=4)
cudnn.benchmark = True
model=optimizermodel.ModelRanger21(filename='HBPASMwithEffv2_ranger21_300circlecrop_trivialaug',lr=0.001,num_batches_per_epoch=len(trainloader))

df=model.traintest(150,trainloader,testloader)
custom_utils.plot_metrics(df)
custom_utils.plot_confusion_matrix_with_max_qwk(df)
torch.cuda.empty_cache()
# Out:
# Model : HBPASM with EfficientNetv2
# Ranger21 optimizer ready with following settings:
#
# Core optimizer = AdamW
# Learning rate of 0.001
#
# Important - num_epochs of training = ** 150 epochs **
# please confirm this is correct or warmup and warmdown will be off
#
# Warm-up: linear warmup, over 2000 iterations
#
# Lookahead active, merging every 5 steps, with blend factor of 0.5
# Norm Loss active, factor = 0.0001
# Stable weight decay of 0.0001
# Gradient Centralization = On
#
# Adaptive Gradient Clipping = True
# 	clipping value of 0.01
# 	steps for clipping = 0.001
#
# Warm-down: Linear warmdown, starting at 72.0%, iteration 8100 of 11250
# warm down will decay until 3e-05 lr
# ----------------------------------------Epoch: 1----------------------------------------
# params size saved
# total param groups = 1
# total params in groups = 466
#  [=======================================>]  Step: 363ms | Tot: 28s583ms | loss: 2.0085 | tra 75/75
#
# Train set: Average loss: 2.0234, Cohen's Kappa: 0.0260, QWK Score: 0.0561, Accuracy: (35.17%), F1-Score: 0.1997, Specificity: 0.8058
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 534ms | Tot: 5s873ms | test 25/25 =================================>......]  Step: 183ms | Tot: 5s191ms | test 22/25
#
# Test set: Average loss: 0.1257, Accuracy: 174/400 (43.50%), Cohen's Kappa: 0.0000, QWK Score: 0.0000, F1-Score: 0.1213, Specificity: 0.8000
# QWK did not improved from 0.0000
# ----------------------------------------Epoch: 2----------------------------------------
#  [=======================================>]  Step: 336ms | Tot: 26s982ms | loss: 1.9843 | tra 75/75
#
# Train set: Average loss: 1.9882, Cohen's Kappa: 0.0000, QWK Score: 0.0000, Accuracy: (45.00%), F1-Score: 0.1241, Specificity: 0.8000
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 494ms | Tot: 5s697ms | test 25/25 ========>..............................]  Step: 70ms | Tot: 1s135ms | test  7/25 =================>......................]  Step: 126ms | Tot: 2s196ms | test 12/25 ====================>...................]  Step: 174ms | Tot: 2s978ms | test 14/25 ===========================>............]  Step: 198ms | Tot: 3s983ms | test 18/25 ==============================>.........]  Step: 119ms | Tot: 4s188ms | test 20/25
#
# Test set: Average loss: 0.1225, Accuracy: 174/400 (43.50%), Cohen's Kappa: 0.0000, QWK Score: 0.0000, F1-Score: 0.1213, Specificity: 0.8000
# QWK did not improved from 0.0000
# ----------------------------------------Epoch: 3----------------------------------------
#  [=======================================>]  Step: 403ms | Tot: 27s600ms | loss: 1.8154 | tra 75/75
#
# Train set: Average loss: 1.8617, Cohen's Kappa: 0.0097, QWK Score: 0.0194, Accuracy: (45.33%), F1-Score: 0.1335, Specificity: 0.8016
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 451ms | Tot: 5s710ms | test 25/25 ==>....................................]  Step: 121ms | Tot: 196ms | test   3/25 =========>..............................]  Step: 133ms | Tot: 1s168ms | test 7/25 ===========>............................]  Step: 65ms | Tot: 1s234ms | test  8/25 ========================>...............]  Step: 64ms | Tot: 3s201ms | test  16/25 ===========================>............]  Step: 201ms | Tot: 3s971ms | test 18/25 ============================>...........]  Step: 190ms | Tot: 4s161ms | test 19/25
#
# Test set: Average loss: 0.1143, Accuracy: 201/400 (50.25%), Cohen's Kappa: 0.1636, QWK Score: 0.3298, F1-Score: 0.2271, Specificity: 0.8290
# Best qwk improved from 0.0000 to 0.3298
# ----------------------------------------Epoch: 4----------------------------------------
#  [=======================================>]  Step: 336ms | Tot: 26s56ms | loss: 1.3570 | tra 75/75
#
# Train set: Average loss: 1.4623, Cohen's Kappa: 0.2389, QWK Score: 0.4718, Accuracy: (53.33%), F1-Score: 0.2435, Specificity: 0.8455
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 611ms | Tot: 5s737ms | test 25/25 ===>...................................]  Step: 63ms | Tot: 191ms | test    4/25 ============================>...........]  Step: 119ms | Tot: 4s39ms | test  19/25 ==============================>.........]  Step: 65ms | Tot: 4s105ms | test  20/25
#
# Test set: Average loss: 0.1042, Accuracy: 230/400 (57.50%), Cohen's Kappa: 0.3413, QWK Score: 0.6811, F1-Score: 0.2783, Specificity: 0.8665
# Best qwk improved from 0.3298 to 0.6811
# ----------------------------------------Epoch: 5----------------------------------------
#  [=======================================>]  Step: 350ms | Tot: 27s506ms | loss: 1.4031 | tra 75/75
#
# Train set: Average loss: 1.1002, Cohen's Kappa: 0.3418, QWK Score: 0.6721, Accuracy: (57.58%), F1-Score: 0.2719, Specificity: 0.8685
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 568ms | Tot: 5s559ms | test 25/25 ========>..............................]  Step: 65ms | Tot: 1s108ms | test  7/25 ================>.......................]  Step: 66ms | Tot: 2s53ms | test   11/25 ===========================>............]  Step: 182ms | Tot: 3s901ms | test 18/25 =================================>......]  Step: 187ms | Tot: 4s862ms | test 22/25
#
# Test set: Average loss: 0.1010, Accuracy: 232/400 (58.00%), Cohen's Kappa: 0.3450, QWK Score: 0.6835, F1-Score: 0.2837, Specificity: 0.8663
# Best qwk improved from 0.6811 to 0.6835
# ----------------------------------------Epoch: 6----------------------------------------
#  [=======================================>]  Step: 356ms | Tot: 28s187ms | loss: 0.5259 | tra 75/75
#
# Train set: Average loss: 0.9332, Cohen's Kappa: 0.3645, QWK Score: 0.7074, Accuracy: (58.33%), F1-Score: 0.2763, Specificity: 0.8751
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 508ms | Tot: 6s18ms | test  25/25 >......................................]  Step: 205ms | Tot: 205ms | test   2/25 ==============================>.........]  Step: 71ms | Tot: 4s513ms | test  20/25
#
# Test set: Average loss: 0.0952, Accuracy: 232/400 (58.00%), Cohen's Kappa: 0.3645, QWK Score: 0.7570, F1-Score: 0.2784, Specificity: 0.8739
# Best qwk improved from 0.6835 to 0.7570
# ----------------------------------------Epoch: 7----------------------------------------
#  [=======================================>]  Step: 356ms | Tot: 26s446ms | loss: 1.2355 | tra 75/75
#
# Train set: Average loss: 0.9196, Cohen's Kappa: 0.3676, QWK Score: 0.7097, Accuracy: (58.50%), F1-Score: 0.2980, Specificity: 0.8758
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 443ms | Tot: 5s660ms | test 25/25 ==>....................................]  Step: 109ms | Tot: 183ms | test   3/25 =========>..............................]  Step: 118ms | Tot: 1s142ms | test 7/25 ===========>............................]  Step: 70ms | Tot: 1s213ms | test  8/25 ===========================>............]  Step: 190ms | Tot: 3s937ms | test 18/25 =================================>......]  Step: 185ms | Tot: 4s968ms | test 22/25
#
# Test set: Average loss: 0.0916, Accuracy: 245/400 (61.25%), Cohen's Kappa: 0.4149, QWK Score: 0.7719, F1-Score: 0.3406, Specificity: 0.8828
# Best qwk improved from 0.7570 to 0.7719
# ----------------------------------------Epoch: 8----------------------------------------
#  [=======================================>]  Step: 374ms | Tot: 26s403ms | loss: 0.6123 | tra 75/75
#
# Train set: Average loss: 0.8075, Cohen's Kappa: 0.4029, QWK Score: 0.7602, Accuracy: (60.33%), F1-Score: 0.3222, Specificity: 0.8838
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 606ms | Tot: 5s915ms | test 25/25 ======================>.................]  Step: 77ms | Tot: 3s61ms | test   15/25 ========================>...............]  Step: 109ms | Tot: 3s171ms | test 16/25 ============================>...........]  Step: 125ms | Tot: 4s104ms | test 19/25 ====================================>...]  Step: 73ms | Tot: 5s308ms | test  24/25
#
# Test set: Average loss: 0.0903, Accuracy: 235/400 (58.75%), Cohen's Kappa: 0.3909, QWK Score: 0.7804, F1-Score: 0.3136, Specificity: 0.8815
# Best qwk improved from 0.7719 to 0.7804
# ----------------------------------------Epoch: 9----------------------------------------
#  [=======================================>]  Step: 324ms | Tot: 26s893ms | loss: 0.6454 | tra 75/75
#
# Train set: Average loss: 0.7089, Cohen's Kappa: 0.4371, QWK Score: 0.8059, Accuracy: (62.17%), F1-Score: 0.3594, Specificity: 0.8913
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 528ms | Tot: 5s934ms | test 25/25 ==========>............................]  Step: 62ms | Tot: 1s198ms | test  8/25 ================>.......................]  Step: 187ms | Tot: 2s125ms | test 11/25 ======================>.................]  Step: 199ms | Tot: 3s170ms | test 15/25 ============================>...........]  Step: 181ms | Tot: 4s260ms | test 19/25
#
# Test set: Average loss: 0.0876, Accuracy: 258/400 (64.50%), Cohen's Kappa: 0.4819, QWK Score: 0.8343, F1-Score: 0.4109, Specificity: 0.8995
# Best qwk improved from 0.7804 to 0.8343
# ----------------------------------------Epoch: 10----------------------------------------
#  [=======================================>]  Step: 333ms | Tot: 27s306ms | loss: 0.6367 | tra 75/75
#
# Train set: Average loss: 0.6914, Cohen's Kappa: 0.4585, QWK Score: 0.8109, Accuracy: (63.17%), F1-Score: 0.4071, Specificity: 0.8958
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 517ms | Tot: 5s827ms | test 25/25 ==>....................................]  Step: 111ms | Tot: 189ms | test   3/25 ====>...................................]  Step: 67ms | Tot: 256ms | test    4/25 =================>......................]  Step: 70ms | Tot: 2s221ms | test  12/25 ===========================>............]  Step: 193ms | Tot: 4s76ms | test  18/25 ====================================>...]  Step: 64ms | Tot: 5s309ms | test  24/25
#
# Test set: Average loss: 0.0874, Accuracy: 266/400 (66.50%), Cohen's Kappa: 0.5211, QWK Score: 0.8266, F1-Score: 0.4704, Specificity: 0.9077
# QWK did not improved from 0.8343
# ----------------------------------------Epoch: 11----------------------------------------
#  [=======================================>]  Step: 346ms | Tot: 27s254ms | loss: 0.7025 | tra 75/75
#
# Train set: Average loss: 0.6272, Cohen's Kappa: 0.5028, QWK Score: 0.8359, Accuracy: (65.50%), F1-Score: 0.4493, Specificity: 0.9060
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 650ms | Tot: 5s957ms | test 25/25 ========>..............................]  Step: 68ms | Tot: 1s95ms | test   7/25 ====================>...................]  Step: 196ms | Tot: 2s986ms | test 14/25
#
# Test set: Average loss: 0.0864, Accuracy: 277/400 (69.25%), Cohen's Kappa: 0.5730, QWK Score: 0.8367, F1-Score: 0.5258, Specificity: 0.9200
# Best qwk improved from 0.8343 to 0.8367
# ----------------------------------------Epoch: 12----------------------------------------
#  [=======================================>]  Step: 378ms | Tot: 27s844ms | loss: 0.3853 | tra 75/75
#
# Train set: Average loss: 0.5724, Cohen's Kappa: 0.5327, QWK Score: 0.8435, Accuracy: (67.92%), F1-Score: 0.4674, Specificity: 0.9104
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 415ms | Tot: 5s943ms | test 25/25 ===>...................................]  Step: 65ms | Tot: 202ms | test    4/25 ================>.......................]  Step: 189ms | Tot: 2s250ms | test 11/25
#
# Test set: Average loss: 0.0877, Accuracy: 266/400 (66.50%), Cohen's Kappa: 0.5356, QWK Score: 0.8271, F1-Score: 0.4963, Specificity: 0.9132
# QWK did not improved from 0.8367
# ----------------------------------------Epoch: 13----------------------------------------
#  [=======================================>]  Step: 372ms | Tot: 26s914ms | loss: 0.5626 | tra 75/75
#
# Train set: Average loss: 0.5564, Cohen's Kappa: 0.5273, QWK Score: 0.8510, Accuracy: (67.17%), F1-Score: 0.4695, Specificity: 0.9107
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 523ms | Tot: 5s924ms | test 25/25 ==>....................................]  Step: 78ms | Tot: 204ms | test    3/25 =========>..............................]  Step: 77ms | Tot: 1s188ms | test  7/25 ===========================>............]  Step: 184ms | Tot: 4s118ms | test 18/25 ====================================>...]  Step: 123ms | Tot: 5s401ms | test 24/25
#
# Test set: Average loss: 0.0884, Accuracy: 263/400 (65.75%), Cohen's Kappa: 0.5012, QWK Score: 0.8181, F1-Score: 0.4609, Specificity: 0.9027
# QWK did not improved from 0.8367
# ----------------------------------------Epoch: 14----------------------------------------
#  [=======================================>]  Step: 324ms | Tot: 27s21ms | loss: 0.8802 | tra 75/75
#
# Train set: Average loss: 0.5127, Cohen's Kappa: 0.6062, QWK Score: 0.8687, Accuracy: (72.58%), F1-Score: 0.5332, Specificity: 0.9262
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 691ms | Tot: 5s944ms | test 25/25 ============================>...........]  Step: 76ms | Tot: 4s165ms | test  19/25
#
# Test set: Average loss: 0.0891, Accuracy: 266/400 (66.50%), Cohen's Kappa: 0.5259, QWK Score: 0.8131, F1-Score: 0.4913, Specificity: 0.9098
# QWK did not improved from 0.8367
# ----------------------------------------Epoch: 15----------------------------------------
#  [=======================================>]  Step: 384ms | Tot: 27s143ms | loss: 0.2312 | tra 75/75
#
# Train set: Average loss: 0.4732, Cohen's Kappa: 0.5787, QWK Score: 0.8797, Accuracy: (70.50%), F1-Score: 0.5060, Specificity: 0.9222
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 522ms | Tot: 5s567ms | test 25/25 ============================>...........]  Step: 61ms | Tot: 3s945ms | test  19/25
#
# Test set: Average loss: 0.0891, Accuracy: 256/400 (64.00%), Cohen's Kappa: 0.4910, QWK Score: 0.7875, F1-Score: 0.4712, Specificity: 0.9031
# QWK did not improved from 0.8367
# ----------------------------------------Epoch: 16----------------------------------------
#  [=======================================>]  Step: 352ms | Tot: 26s18ms | loss: 0.5051 | tra 75/75
#
# Train set: Average loss: 0.4727, Cohen's Kappa: 0.5989, QWK Score: 0.8790, Accuracy: (71.92%), F1-Score: 0.5482, Specificity: 0.9246
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 629ms | Tot: 5s931ms | test 25/25
#
# Test set: Average loss: 0.0873, Accuracy: 254/400 (63.50%), Cohen's Kappa: 0.4992, QWK Score: 0.8123, F1-Score: 0.5039, Specificity: 0.9056
# QWK did not improved from 0.8367
# ----------------------------------------Epoch: 17----------------------------------------
#  [=======================================>]  Step: 349ms | Tot: 26s94ms | loss: 0.3163 | tra 75/75
#
# Train set: Average loss: 0.4511, Cohen's Kappa: 0.6374, QWK Score: 0.8803, Accuracy: (74.17%), F1-Score: 0.6334, Specificity: 0.9325
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 502ms | Tot: 5s523ms | test 25/25 ========================>...............]  Step: 76ms | Tot: 3s61ms | test   16/25 ============================>...........]  Step: 189ms | Tot: 4s34ms | test  19/25
#
# Test set: Average loss: 0.0899, Accuracy: 260/400 (65.00%), Cohen's Kappa: 0.5093, QWK Score: 0.7969, F1-Score: 0.5495, Specificity: 0.9067
# QWK did not improved from 0.8367
# ----------------------------------------Epoch: 18----------------------------------------
#  [=======================================>]  Step: 365ms | Tot: 26s894ms | loss: 0.7404 | tra 75/75
#
# Train set: Average loss: 0.4301, Cohen's Kappa: 0.6654, QWK Score: 0.8940, Accuracy: (76.33%), F1-Score: 0.6754, Specificity: 0.9375
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 622ms | Tot: 5s634ms | test 25/25 ==============================>.........]  Step: 63ms | Tot: 4s47ms | test   20/25 ====================================>...]  Step: 65ms | Tot: 5s11ms | test   24/25
#
# Test set: Average loss: 0.0881, Accuracy: 278/400 (69.50%), Cohen's Kappa: 0.5689, QWK Score: 0.8301, F1-Score: 0.5855, Specificity: 0.9171
# QWK did not improved from 0.8367
# ----------------------------------------Epoch: 19----------------------------------------
#  [=======================================>]  Step: 327ms | Tot: 26s413ms | loss: 0.3164 | tra 75/75
#
# Train set: Average loss: 0.3871, Cohen's Kappa: 0.6853, QWK Score: 0.9033, Accuracy: (77.75%), F1-Score: 0.7037, Specificity: 0.9411
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 381ms | Tot: 6s159ms | test 25/25 ==>....................................]  Step: 66ms | Tot: 193ms | test    3/25 ==============================>.........]  Step: 193ms | Tot: 4s673ms | test 20/25
#
# Test set: Average loss: 0.0892, Accuracy: 255/400 (63.75%), Cohen's Kappa: 0.5088, QWK Score: 0.7963, F1-Score: 0.5592, Specificity: 0.9083
# QWK did not improved from 0.8367
# ----------------------------------------Epoch: 20----------------------------------------
#  [=======================================>]  Step: 318ms | Tot: 26s654ms | loss: 0.2105 | tra 75/75
#
# Train set: Average loss: 0.4354, Cohen's Kappa: 0.6684, QWK Score: 0.8809, Accuracy: (76.25%), F1-Score: 0.7057, Specificity: 0.9384
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 606ms | Tot: 5s705ms | test 25/25 =================>......................]  Step: 120ms | Tot: 2s140ms | test 12/25
#
# Test set: Average loss: 0.0862, Accuracy: 268/400 (67.00%), Cohen's Kappa: 0.5399, QWK Score: 0.8195, F1-Score: 0.5827, Specificity: 0.9130
# QWK did not improved from 0.8367
# ----------------------------------------Epoch: 21----------------------------------------
#  [=======================================>]  Step: 314ms | Tot: 25s961ms | loss: 0.2229 | tra 75/75
#
# Train set: Average loss: 0.3901, Cohen's Kappa: 0.7160, QWK Score: 0.9056, Accuracy: (79.75%), F1-Score: 0.7365, Specificity: 0.9471
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 450ms | Tot: 5s607ms | test 25/25 ==>....................................]  Step: 128ms | Tot: 191ms | test   3/25 ====>...................................]  Step: 76ms | Tot: 267ms | test    4/25 ========================>...............]  Step: 64ms | Tot: 3s128ms | test  16/25
#
# Test set: Average loss: 0.0896, Accuracy: 272/400 (68.00%), Cohen's Kappa: 0.5387, QWK Score: 0.8158, F1-Score: 0.5867, Specificity: 0.9092
# QWK did not improved from 0.8367
# ----------------------------------------Epoch: 22----------------------------------------
#  [=======================================>]  Step: 364ms | Tot: 26s217ms | loss: 0.2671 | tra 75/75
#
# Train set: Average loss: 0.3878, Cohen's Kappa: 0.7191, QWK Score: 0.9089, Accuracy: (80.08%), F1-Score: 0.7421, Specificity: 0.9474
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 503ms | Tot: 5s715ms | test 25/25 ===>...................................]  Step: 125ms | Tot: 301ms | test   4/25 =========>..............................]  Step: 81ms | Tot: 1s140ms | test  7/25 ================>.......................]  Step: 93ms | Tot: 2s111ms | test  11/25 ====================>...................]  Step: 209ms | Tot: 3s8ms | test   14/25 ========================>...............]  Step: 96ms | Tot: 3s204ms | test  16/25 ==============================>.........]  Step: 67ms | Tot: 4s236ms | test  20/25 =================================>......]  Step: 200ms | Tot: 5s56ms | test  22/25
#
# Test set: Average loss: 0.0890, Accuracy: 280/400 (70.00%), Cohen's Kappa: 0.5823, QWK Score: 0.8283, F1-Score: 0.6258, Specificity: 0.9204
# QWK did not improved from 0.8367
# ----------------------------------------Epoch: 23----------------------------------------
#  [=======================================>]  Step: 339ms | Tot: 27s226ms | loss: 0.3696 | tra 75/75
#
# Train set: Average loss: 0.3636, Cohen's Kappa: 0.7213, QWK Score: 0.9082, Accuracy: (80.17%), F1-Score: 0.7555, Specificity: 0.9473
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 538ms | Tot: 5s767ms | test 25/25 ==>....................................]  Step: 116ms | Tot: 186ms | test   3/25 ====>...................................]  Step: 77ms | Tot: 264ms | test    4/25 =========>..............................]  Step: 71ms | Tot: 1s141ms | test  7/25
#
# Test set: Average loss: 0.0875, Accuracy: 268/400 (67.00%), Cohen's Kappa: 0.5456, QWK Score: 0.8287, F1-Score: 0.5843, Specificity: 0.9145
# QWK did not improved from 0.8367
# ----------------------------------------Epoch: 24----------------------------------------
#  [=======================================>]  Step: 356ms | Tot: 27s387ms | loss: 0.4600 | tra 75/75
#
# Train set: Average loss: 0.3745, Cohen's Kappa: 0.7149, QWK Score: 0.9115, Accuracy: (79.67%), F1-Score: 0.7309, Specificity: 0.9477
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 523ms | Tot: 5s715ms | test 25/25 ===>...................................]  Step: 66ms | Tot: 269ms | test    4/25 ===========================>............]  Step: 194ms | Tot: 3s984ms | test 18/25 ==============================>.........]  Step: 96ms | Tot: 4s161ms | test  20/25
#
# Test set: Average loss: 0.0892, Accuracy: 257/400 (64.25%), Cohen's Kappa: 0.5088, QWK Score: 0.8003, F1-Score: 0.5206, Specificity: 0.9074
# QWK did not improved from 0.8367
# ----------------------------------------Epoch: 25----------------------------------------
#  [=======================================>]  Step: 357ms | Tot: 27s260ms | loss: 0.4676 | tra 75/75
#
# Train set: Average loss: 0.3750, Cohen's Kappa: 0.7326, QWK Score: 0.9074, Accuracy: (80.92%), F1-Score: 0.7680, Specificity: 0.9505
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 477ms | Tot: 5s684ms | test 25/25 =======>...............................]  Step: 187ms | Tot: 1s139ms | test 6/25 ====================================>...]  Step: 67ms | Tot: 5s206ms | test  24/25
#
# Test set: Average loss: 0.0882, Accuracy: 266/400 (66.50%), Cohen's Kappa: 0.5422, QWK Score: 0.8266, F1-Score: 0.5903, Specificity: 0.9138
# QWK did not improved from 0.8367
# ----------------------------------------Epoch: 26----------------------------------------
#  [=======================================>]  Step: 360ms | Tot: 27s99ms | loss: 0.5856 | tra 75/75
#
# Train set: Average loss: 0.3462, Cohen's Kappa: 0.7539, QWK Score: 0.9175, Accuracy: (82.50%), F1-Score: 0.7670, Specificity: 0.9545
# ----------------------------------------Test---------------------------------------------
#  [======================================>.]  Step: 543ms | Tot: 5s787ms | test 25/25 =================>......................]  Step: 70ms | Tot: 2s120ms | test  12/25 ======================>.................]  Step: 124ms | Tot: 3s37ms | test  15/25 ========================>...............]  Step: 70ms | Tot: 3s108ms | test  16/25 ============================>...........]  Step: 184ms | Tot: 4s128ms | test 19/25
#
# Test set: Average loss: 0.0861, Accuracy: 286/400 (71.50%), Cohen's Kappa: 0.5990, QWK Score: 0.8283, F1-Score: 0.6195, Specificity: 0.9227
# QWK did not improved from 0.8367
# No improvement in validation loss for 15 epochs. Early stopping.
# Training time: 00:19:05.92
# Save filename :  HBPASMwithEffv2_ranger21_300circlecrop_trivialaug

# %% [markdown]
# # augmix

# %%
IMG_SIZE=300
image_dir = os.path.join('..', 'dataset','ben processed circle crop','deepdridtrain')
trainset = datasets.ImageFolder(image_dir, transform=transforms.Compose([
                                                transforms.Resize((IMG_SIZE, IMG_SIZE), Image.BILINEAR),
                                                augment.AugMix(),
                                                transforms.ToTensor(),
                                                ]))
trainloader = torch.utils.data.DataLoader(trainset, batch_size=16,
                                          shuffle=True, num_workers=4)

image_dir = os.path.join('..', 'dataset','ben processed circle crop','deepdridvalid')
testset = datasets.ImageFolder(image_dir, transform=transforms.Compose([
                                                transforms.Resize((IMG_SIZE, IMG_SIZE), Image.BILINEAR),
                                                transforms.ToTensor(),
                                                ]))
testloader = torch.utils.data.DataLoader(testset, batch_size=16,
                                         shuffle=False, num_workers=4)
cudnn.benchmark = True
model=optimizermodel.ModelRanger21(filename='HBPASMwithEffv2_ranger21_300circlecrop_augmix',lr=0.001,num_batches_per_epoch=len(trainloader))

df=model.traintest(150,trainloader,testloader)
custom_utils.plot_metrics(df)
custom_utils.plot_confusion_matrix_with_max_qwk(df)
torch.cuda.empty_cache()
# Out:
# Model : HBPASM with EfficientNetv2
# Ranger21 optimizer ready with following settings:
#
# Core optimizer = AdamW
# Learning rate of 0.001
#
# Important - num_epochs of training = ** 150 epochs **
# please confirm this is correct or warmup and warmdown will be off
#
# Warm-up: linear warmup, over 2000 iterations
#
# Lookahead active, merging every 5 steps, with blend factor of 0.5
# Norm Loss active, factor = 0.0001
# Stable weight decay of 0.0001
# Gradient Centralization = On
#
# Adaptive Gradient Clipping = True
# 	clipping value of 0.01
# 	steps for clipping = 0.001
#
# Warm-down: Linear warmdown, starting at 72.0%, iteration 8100 of 11250
# warm down will decay until 3e-05 lr
# ----------------------------------------Epoch: 1----------------------------------------
# params size saved
# total param groups = 1
# total params in groups = 466
#  [=========================>..............]  Step: 362ms | Tot: 19s932ms | loss: 2.0204 | tra 48/75
#  [=======================================>]  Step: 385ms | Tot: 32s94ms | loss: 2.0027 | tra 75/75
#
# Train set: Average loss: 2.0238, Cohen's Kappa: 0.0100, QWK Score: 0.0569, Accuracy: (34.08%), F1-Score: 0.1765, Specificity: 0.8027
# ----------------------------------------Test---------------------------------------------

# %% [markdown]
# # gridmask

# %%
class GridMask(DualTransform):

    def __init__(self, num_grid=3, fill_value=0, rotate=0, mode=0, always_apply=False, p=0.5,gridsize=4):
        super(GridMask, self).__init__(always_apply, p)
        if isinstance(num_grid, int):
            num_grid = (num_grid, num_grid)
        if isinstance(rotate, int):
            rotate = (-rotate, rotate)
        self.num_grid = num_grid
        self.fill_value = fill_value
        self.rotate = rotate
        self.mode = mode
        self.masks = None
        self.gridsize=4
        self.rand_h_max = []
        self.rand_w_max = []

    def init_masks(self, height, width):
        if self.masks is None:
            self.masks = []
            n_masks = self.num_grid[1] - self.num_grid[0] + 1
            for n, n_g in enumerate(range(self.num_grid[0], self.num_grid[1] + 1, 1)):
                grid_h = height / n_g
                grid_w = width / n_g
                this_mask = np.ones((int((n_g + 1) * grid_h), int((n_g + 1) * grid_w))).astype(np.uint8)
                for i in range(n_g + 1):
                    for j in range(n_g + 1):
                        this_mask[
                            #/ 1.3 when fill mode =2 
                             int(i * grid_h) : int(i * grid_h + grid_h / self.gridsize),
                             int(j * grid_w) : int(j * grid_w + grid_w / self.gridsize)
                        ] = self.fill_value
                        if self.mode == 2:
                            this_mask[
                                 int(i * grid_h + grid_h / 2) : int(i * grid_h + grid_h),
                                 int(j * grid_w + grid_w / 2) : int(j * grid_w + grid_w)
                            ] = self.fill_value
                
                if self.mode == 1:
                    this_mask = 1 - this_mask

                self.masks.append(this_mask)
                self.rand_h_max.append(grid_h)
                self.rand_w_max.append(grid_w)

    def apply(self, image, mask, rand_h, rand_w, angle, **params):
        h, w = image.shape[:2]
        
        #mask = AF.rotate(mask, angle) if self.rotate[1] > 0 else mask
        pil_image = Image.fromarray(mask)
        pil_image = pil_image.rotate(0)
        mask = np.array(pil_image)
        mask = mask[:,:,np.newaxis] if image.ndim == 3 else mask
        image *= mask[rand_h:rand_h+h, rand_w:rand_w+w].astype(image.dtype)
        return image

    def get_params_dependent_on_targets(self, params):
        img = params['image']
        height, width = img.shape[:2]
        self.init_masks(height, width)

        mid = np.random.randint(len(self.masks))
        mask = self.masks[mid]
        rand_h = np.random.randint(self.rand_h_max[mid])
        rand_w = np.random.randint(self.rand_w_max[mid])
        angle = np.random.randint(self.rotate[0], self.rotate[1]) if self.rotate[1] > 0 else 0

        return {'mask': mask, 'rand_h': rand_h, 'rand_w': rand_w, 'angle': angle}

    @property
    def targets_as_params(self):
        return ['image']

    def get_transform_init_args_names(self):
        return ('num_grid', 'fill_value', 'rotate', 'mode')
IMG_SIZE=300
image_dir = os.path.join('..', 'dataset','ben processed circle crop','deepdridtrain')
trainset = CustomImageFolder(image_dir, transform=A.Compose([
                                                    A.Resize(IMG_SIZE, IMG_SIZE), 
                                                    GridMask(num_grid=5, mode=0,rotate=10,always_apply=True,gridsize=4),
                                                    A.Normalize(
                                                        mean=[0.485, 0.456, 0.406],
                                                        std=[0.229, 0.224, 0.225],
                                                    ),
                                                    ToTensorV2()
                                                ]))
trainloader = torch.utils.data.DataLoader(trainset, batch_size=16,
                                          shuffle=True)
image_dir = os.path.join('..', 'dataset','ben processed circle crop','deepdridvalid')
testset = CustomImageFolder(image_dir, transform=A.Compose([
                                                    A.Resize(IMG_SIZE, IMG_SIZE), 
                                                    A.Normalize(
                                                        mean=[0.485, 0.456, 0.406],
                                                        std=[0.229, 0.224, 0.225],
                                                    ),
                                                    ToTensorV2()
                                                ]))
testloader = torch.utils.data.DataLoader(testset, batch_size=16,
                                         shuffle=False)
cudnn.benchmark = True

def visualize_augmentations(dataset, idx=0, samples=10, cols=5):
    dataset = copy.deepcopy(dataset)
    dataset.transform = A.Compose([t for t in dataset.transform if not isinstance(t, (A.Normalize, ToTensorV2))])
    rows = samples // cols
    figure, ax = plt.subplots(nrows=rows, ncols=cols, figsize=(12, 6))
    for i in range(samples):
        image, _ = dataset[idx]
        ax.ravel()[i].imshow(image)
        ax.ravel()[i].set_axis_off()
    plt.tight_layout()
    plt.show()
visualize_augmentations(trainset)
model=optimizermodel.Ranger21(filename='HBPASMwithEffv2_ranger21_300circlecrop_gridmask',lr=0.001,num_batches_per_epoch=len(trainloader))

df=model.traintest(150,trainloader,testloader)
custom_utils.plot_metrics(df)
custom_utils.plot_confusion_matrix_with_max_qwk(df)
torch.cuda.empty_cache()

# %% [markdown]
# # fencemask

# %%
class FenceMask(DualTransform):

    def __init__(self, num_grid=3, fill_value=0, rotate=0, mode=0, always_apply=False, p=0.5,gridsize=4):
        super(FenceMask, self).__init__(always_apply, p)
        if isinstance(num_grid, int):
            num_grid = (num_grid, num_grid)
        if isinstance(rotate, int):
            rotate = (-rotate, rotate)
        self.num_grid = num_grid
        self.fill_value = fill_value
        self.rotate = rotate
        self.mode = mode
        self.masks = None
        self.gridsize=4
        self.rand_h_max = []
        self.rand_w_max = []

    def init_masks(self, height, width):
        if self.masks is None:
            self.masks = []
            n_masks = self.num_grid[1] - self.num_grid[0] + 1
            for n, n_g in enumerate(range(self.num_grid[0], self.num_grid[1] + 1, 1)):
                grid_h = height / n_g+15
                grid_w = width / n_g+15
                this_mask = np.ones((int((n_g + 1) * grid_h), int((n_g + 1) * grid_w))).astype(np.uint8)
                for i in range(n_g + 1):
                    for j in range(n_g + 1):
                        this_mask[
                            #/ 1.3 when fill mode =2 
                             int(i * grid_h) : int(i * grid_h + grid_h / self.gridsize+25),
                             int(j * grid_w) : int(j * grid_w + grid_w / self.gridsize+25)
                        ] = self.fill_value
                        if self.mode == 2:
                            this_mask[
                                 int(i * grid_h + grid_h / 2) : int(i * grid_h + grid_h),
                                 int(j * grid_w + grid_w / 2) : int(j * grid_w + grid_w)
                            ] = self.fill_value
                
                if self.mode == 1:
                    this_mask = 1 - this_mask

                self.masks.append(this_mask)
                self.rand_h_max.append(grid_h)
                self.rand_w_max.append(grid_w)

    def apply(self, image, mask, rand_h, rand_w, angle, **params):
        h, w = image.shape[:2]
        
        #mask = AF.rotate(mask, angle) if self.rotate[1] > 0 else mask
        pil_image = Image.fromarray(mask)
        pil_image = pil_image.rotate(0)
        mask = np.array(pil_image)
        mask = mask[:,:,np.newaxis] if image.ndim == 3 else mask
        image *= mask[rand_h:rand_h+h, rand_w:rand_w+w].astype(image.dtype)
        return image

    def get_params_dependent_on_targets(self, params):
        img = params['image']
        height, width = img.shape[:2]
        self.init_masks(height, width)

        mid = np.random.randint(len(self.masks))
        mask = self.masks[mid]
        rand_h = np.random.randint(self.rand_h_max[mid])
        rand_w = np.random.randint(self.rand_w_max[mid])
        angle = np.random.randint(self.rotate[0], self.rotate[1]) if self.rotate[1] > 0 else 0

        return {'mask': mask, 'rand_h': rand_h, 'rand_w': rand_w, 'angle': angle}

    @property
    def targets_as_params(self):
        return ['image']

    def get_transform_init_args_names(self):
        return ('num_grid', 'fill_value', 'rotate', 'mode')
    
IMG_SIZE=300
image_dir = os.path.join('..', 'dataset','ben processed circle crop','deepdridtrain')
trainset = CustomImageFolder(image_dir, transform=A.Compose([
                                                    A.Resize(IMG_SIZE, IMG_SIZE), 
                                                    FenceMask(num_grid=15, mode=1,rotate=10,always_apply=True,gridsize=1.25),
                                                    A.Normalize(
                                                        mean=[0.485, 0.456, 0.406],
                                                        std=[0.229, 0.224, 0.225],
                                                    ),
                                                    ToTensorV2()
                                                ]))
trainloader = torch.utils.data.DataLoader(trainset, batch_size=16,
                                          shuffle=True)
image_dir = os.path.join('..', 'dataset','ben processed circle crop','deepdridvalid')
testset = CustomImageFolder(image_dir, transform=A.Compose([
                                                    A.Resize(IMG_SIZE, IMG_SIZE), 
                                                    A.Normalize(
                                                        mean=[0.485, 0.456, 0.406],
                                                        std=[0.229, 0.224, 0.225],
                                                    ),
                                                    ToTensorV2()
                                                ]))
testloader = torch.utils.data.DataLoader(testset, batch_size=16,
                                         shuffle=False)

def visualize_augmentations(dataset, idx=0, samples=10, cols=5):
    dataset = copy.deepcopy(dataset)
    dataset.transform = A.Compose([t for t in dataset.transform if not isinstance(t, (A.Normalize, ToTensorV2))])
    rows = samples // cols
    figure, ax = plt.subplots(nrows=rows, ncols=cols, figsize=(12, 6))
    for i in range(samples):
        image, _ = dataset[idx]
        ax.ravel()[i].imshow(image)
        ax.ravel()[i].set_axis_off()
    plt.tight_layout()
    plt.show()
visualize_augmentations(trainset)
cudnn.benchmark = True
model=optimizermodel.ModelRanger21(filename='HBPASMwithEffv2_ranger21_300circlecrop_fencemask',lr=0.001,num_batches_per_epoch=len(trainloader))

df=model.traintest(150,trainloader,testloader)
custom_utils.plot_metrics(df)
custom_utils.plot_confusion_matrix_with_max_qwk(df)
torch.cuda.empty_cache()

# %% [markdown]
# # resample normal aug

# %%
from torchsampler import ImbalancedDatasetSampler
def countLabel(trainloader):
    class_counts = {}
    total_samples = 0

    for images, labels in trainloader:
        for label in labels:
            if label.item() in class_counts:
                class_counts[label.item()] += 1
            else:
                class_counts[label.item()] = 1
            total_samples += 1

    print("Total Samples:", total_samples)
    print("Class Distribution:")
    labels = list(class_counts.keys())
    counts = list(class_counts.values())

    # Plotting the class distribution
    plt.figure(figsize=(10, 5))
    plt.bar(labels, counts)
    plt.xlabel('Class Label')
    plt.ylabel('Number of Samples')
    plt.title('Class Distribution')
    plt.show()

IMG_SIZE=300
image_dir = os.path.join('..', 'dataset','ben processed circle crop','deepdridtrain')
trainset = datasets.ImageFolder(image_dir, transform=transforms.Compose([
                                                transforms.Resize((IMG_SIZE, IMG_SIZE), Image.BILINEAR),
                                                transforms.RandomHorizontalFlip(),
                                                transforms.RandomVerticalFlip(),
                                                transforms.ToTensor(),
                                                ]))
trainloader = torch.utils.data.DataLoader(trainset,sampler=ImbalancedDatasetSampler(trainset), batch_size=16,
                                          )

image_dir = os.path.join('..', 'dataset','ben processed circle crop','deepdridvalid')
testset = datasets.ImageFolder(image_dir, transform=transforms.Compose([
                                                transforms.Resize((IMG_SIZE, IMG_SIZE), Image.BILINEAR),
                                                transforms.ToTensor(),
                                                ]))
testloader = torch.utils.data.DataLoader(testset, batch_size=16,
                                         shuffle=False)
cudnn.benchmark = True
countLabel(trainloader)
cudnn.benchmark = True
model=optimizermodel.ModelRanger21(filename='HBPASMwithEffv2_ranger21_300circlecrop_resample_normalaug',lr=0.001,num_batches_per_epoch=len(trainloader))

df=model.traintest(150,trainloader,testloader)
custom_utils.plot_metrics(df)
custom_utils.plot_confusion_matrix_with_max_qwk(df)
torch.cuda.empty_cache()

# %% [markdown]
# # resample rand aug

# %%
IMG_SIZE=300
image_dir = os.path.join('..', 'dataset','ben processed circle crop','deepdridtrain')
trainset = datasets.ImageFolder(image_dir, transform=transforms.Compose([
                                                transforms.Resize((IMG_SIZE, IMG_SIZE), Image.BILINEAR),
                                                augment.RandAugment(),
                                                transforms.ToTensor(),
                                                ]))
trainloader = torch.utils.data.DataLoader(trainset,sampler=ImbalancedDatasetSampler(trainset), batch_size=16,
                                          )

image_dir = os.path.join('..', 'dataset','ben processed circle crop','deepdridvalid')
testset = datasets.ImageFolder(image_dir, transform=transforms.Compose([
                                                transforms.Resize((IMG_SIZE, IMG_SIZE), Image.BILINEAR),
                                                transforms.ToTensor(),
                                                ]))
testloader = torch.utils.data.DataLoader(testset, batch_size=16,
                                         shuffle=False)
cudnn.benchmark = True
countLabel(trainloader)
cudnn.benchmark = True
model=optimizermodel.ModelRanger21(filename='HBPASMwithEffv2_ranger21_300circlecrop_resample_randaug',lr=0.001,num_batches_per_epoch=len(trainloader))

df=model.traintest(150,trainloader,testloader)
custom_utils.plot_metrics(df)
custom_utils.plot_confusion_matrix_with_max_qwk(df)
torch.cuda.empty_cache()
